# %%
# 필요 모델 호출
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import time
import random

# %%
def seed_everything(seed: int = 2020):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
class config:
    seed = 2020

# %%
seed_everything(config.seed)

# %%
# 이미지 로드
imglist = os.listdir('/Users/User/303/CDAE_chest128px/train/')
def load_image(path):
    image_list = np.zeros((len(imglist), 128, 128))
    for i in range(len(imglist)):
        img = Image.open('/Users/User/303/CDAE_chest128px/train/'+str(imglist[i])).convert('L')
        image_list[i] = img
    return image_list

# %%
posi = load_image('/Users/User/303/CDAE_chest128px/train/*.jpg')
posi = posi.astype('float32')/255.
print(posi.shape)
# Out:
# (6334, 128, 128)

# %%
def train_test_split(img):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(img))
    train_idx = perm[:int(0.8 * len(img))]
    test_idx = perm[int(0.8 * len(img)):]
    return img[train_idx], img[test_idx]

x_train, x_test = train_test_split(posi)
print(x_train.shape, x_test.shape)
# Out:
# (5067, 128, 128) (1267, 128, 128)

# %%
def noisy(noise_typ,image):
    #Gaussian Noisy
    if noise_typ == "gauss":
        
        noisy = image + 0.1 *  np.random.normal(loc=0,scale=1.,size=image.shape)
        return noisy
    #Salt & Pepper Noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 0.05
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
        out[tuple(coords)] = 1
        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[tuple(coords)] = 0
        return out

    # Speckle Noisy
    elif noise_typ =="speckle":
        noisy = np.random.normal(loc=0,scale=1.,size=image.shape)
        noisy = image+ image * 0.1 *noisy
        return noisy

# %%
def MAE(img1, img2):
    D = np.array(img1 - img2, dtype=np.float64)
    D[:, :] = np.abs(D[:, :])
    MAE = D.sum()/img1.size
    return MAE

def PSNR(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 1.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
from skimage.restoration import denoise_nl_means
from scipy.signal import medfilt2d
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance

def Meanfilter(noisy_test_data):
    meanfilter = []
    for i in range(len(noisy_test_data)):
         meanfilter.append(cv2.blur(noisy_test_data[i],(3,3)))
    meanfilter = np.array(meanfilter)
    return meanfilter
    
def Medianfilter(noisy_test_data):
    medianfilter = []
    for i in range(len(noisy_test_data)):
        medianfilter.append(medfilt2d(noisy_test_data[i],(3,3)))
    medianfilter = np.array(medianfilter)
    return medianfilter


def lee_filter(img):
    lee = []
    for i in range(len(img)):
        img_mean = uniform_filter(img[i])
        img_sqr_mean = uniform_filter(img[i]**2)
        img_variance = img_sqr_mean - img_mean**2
        
        overall_variance = variance(img[i])
        
        img_weights = (img_variance**2) / ((img_variance**2) + (overall_variance**2))
        img_output = img_mean + img_weights * (img[i] - img_mean)
        
        lee.append(img_output)
    lee = np.array(lee)
    return lee

# %%
# Add Noisy
x_train_sp_noisy = noisy("gauss",x_train)
x_test_sp_noisy = noisy("gauss",x_test)

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# Salt & Pepper Noisy Image
ax = plt.subplot()
plt.imshow(x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Gauss Noisy Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# MeanFilter Image
start = time.time()
mean_x_test_sp_noisy = Meanfilter(x_test_sp_noisy)
end = time.time()
Meantime= end - start
print("CPU 시간 : "+str(Meantime))

ax = plt.subplot()
plt.imshow(mean_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Gauss Noisy Meanfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.15618515014648438

# %%
# MedianFilter Image
start = time.time()
median_x_test_sp_noisy = Medianfilter(x_test_sp_noisy)
end = time.time()
Mediantime= end - start
print("CPU 시간 : "+str(Mediantime))

ax = plt.subplot()
plt.imshow(median_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Gauss Noisy Medianfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 1.7183752059936523

# %%
# LeeFilter Image
start = time.time()
lee_x_test_sp_noisy = lee_filter(x_test_sp_noisy)
end = time.time()
Leetime= end - start
print("CPU 시간 : "+str(Leetime))

ax = plt.subplot()
plt.imshow(lee_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Gauss Noisy lee_filter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.6248817443847656

# %%
#Convolution Neural Networks Filter Image
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, UpSampling2D
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from keras import optimizers
from keras.models import Model

# %%
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D ,LeakyReLU,ReLU,Concatenate
from keras import optimizers
from keras.models import Model

# %%
epochs = 100
inChannel = 1
x, y = 128, 128
input_img = Input(shape=(x,y,inChannel))

# %%
act=LeakyReLU(alpha=0.01)
#act=ReLU()

# %%
# Encoder

conv1 = Conv2D(16, (3,3), activation=act, padding='same',name='encoder1_cov')(input_img) 
pool1 = MaxPooling2D(pool_size=(2,2),name='maxpool1')(conv1) 
conv2 = Conv2D(32, (3,3), activation=act, padding='same',name='encoder2_cov')(pool1)
pool2 = MaxPooling2D(pool_size=(2,2),name='maxpool2')(conv2) 
encoded = Conv2D(64, (3,3), activation=act, padding='same',name='encoder3_cov')(pool2) 

# Decoder1
conv4 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder1_cov')(encoded)
up1 = UpSampling2D((2,2),name='up1')(conv4)
conv5 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder2_cov')(up1)
up2 = UpSampling2D((2,2),name='up2')(conv5)

# Decoder2
conv6 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder3_cov')(encoded)
up3 = UpSampling2D((2,2),name='up3')(conv6)
conv7 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder4_cov')(up3)
up4 = UpSampling2D((2,2),name='up4')(conv7)
#Merge
con=Concatenate()([up2,up4])
conv8 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder5_cov')(con)
decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same',name='result_cov')(conv8)

# %%
# CAEFilter Image
autoencoder_sp = Model(input_img, decoded)
autoencoder_sp.compile(loss='mean_squared_error',optimizer=optimizers.Adam())
autoencoder_sp.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  encoder1_cov (Conv2D)          (None, 128, 128, 16  160         ['input_2[0][0]']
#                                 )
#
#  maxpool1 (MaxPooling2D)        (None, 64, 64, 16)   0           ['encoder1_cov[0][0]']
#
#  encoder2_cov (Conv2D)          (None, 64, 64, 32)   4640        ['maxpool1[0][0]']
#
#  maxpool2 (MaxPooling2D)        (None, 32, 32, 32)   0           ['encoder2_cov[0][0]']
#
#  encoder3_cov (Conv2D)          (None, 32, 32, 64)   18496       ['maxpool2[0][0]']
#
#  decoder1_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  decoder3_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  up1 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder1_cov[0][0]']
#
#  up3 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder3_cov[0][0]']
#
#  decoder2_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up1[0][0]']
#
#  decoder4_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up3[0][0]']
#
#  up2 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder2_cov[0][0]']
#                                 )
#
#  up4 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder4_cov[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 64  0           ['up2[0][0]',
#                                 )                                 'up4[0][0]']
#
#  decoder5_cov (Conv2D)          (None, 128, 128, 64  36928       ['concatenate_1[0][0]']
#                                 )
#
#  result_cov (Conv2D)            (None, 128, 128, 1)  577         ['decoder5_cov[0][0]']
#
# ==================================================================================================
# Total params: 171,585
# Trainable params: 171,585
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train_cae = x_train.reshape(5067, 128, 128, 1)
x_test_cae = x_test.reshape(1267, 128, 128,1)
x_train_cae_sp_noisy = x_train_sp_noisy.reshape(5067, 128, 128, 1)
x_test_cae_sp_noisy = x_test_sp_noisy.reshape(1267, 128, 128,1)

# %%
autoencodersp_train = autoencoder_sp.fit(x_train_cae_sp_noisy, x_train_cae, 
                                    batch_size=9, 
                                    epochs=epochs, 
                                    verbose=2,
                                    validation_data=(x_test_cae_sp_noisy, x_test_cae))
# Out:
# Epoch 1/100
# 563/563 - 5s - loss: 0.0029 - val_loss: 0.0011 - 5s/epoch - 9ms/step
# Epoch 2/100
# 563/563 - 5s - loss: 0.0010 - val_loss: 8.8287e-04 - 5s/epoch - 8ms/step
# Epoch 3/100
# 563/563 - 5s - loss: 9.0429e-04 - val_loss: 8.2346e-04 - 5s/epoch - 8ms/step
# Epoch 4/100
# 563/563 - 5s - loss: 8.2445e-04 - val_loss: 7.6415e-04 - 5s/epoch - 8ms/step
# Epoch 5/100
# 563/563 - 5s - loss: 7.9152e-04 - val_loss: 7.4231e-04 - 5s/epoch - 8ms/step
# Epoch 6/100
# 563/563 - 5s - loss: 7.5261e-04 - val_loss: 8.7446e-04 - 5s/epoch - 8ms/step
# Epoch 7/100
# 563/563 - 5s - loss: 7.3728e-04 - val_loss: 7.4650e-04 - 5s/epoch - 8ms/step
# Epoch 8/100
# 563/563 - 5s - loss: 7.2490e-04 - val_loss: 7.1080e-04 - 5s/epoch - 8ms/step
# Epoch 9/100
# 563/563 - 5s - loss: 7.0118e-04 - val_loss: 7.1122e-04 - 5s/epoch - 8ms/step
# Epoch 10/100
# 563/563 - 5s - loss: 6.9498e-04 - val_loss: 6.6845e-04 - 5s/epoch - 8ms/step
# Epoch 11/100
# 563/563 - 5s - loss: 6.8565e-04 - val_loss: 6.7641e-04 - 5s/epoch - 9ms/step
# Epoch 12/100
# 563/563 - 5s - loss: 6.6194e-04 - val_loss: 8.7106e-04 - 5s/epoch - 9ms/step
# Epoch 13/100
# 563/563 - 5s - loss: 6.6489e-04 - val_loss: 6.5526e-04 - 5s/epoch - 9ms/step
# Epoch 14/100
# 563/563 - 5s - loss: 6.6127e-04 - val_loss: 6.8145e-04 - 5s/epoch - 9ms/step
# Epoch 15/100
# 563/563 - 5s - loss: 6.4434e-04 - val_loss: 6.3342e-04 - 5s/epoch - 9ms/step
# Epoch 16/100
# 563/563 - 5s - loss: 6.3788e-04 - val_loss: 6.2547e-04 - 5s/epoch - 9ms/step
# Epoch 17/100
# 563/563 - 5s - loss: 6.4095e-04 - val_loss: 6.2788e-04 - 5s/epoch - 9ms/step
# Epoch 18/100
# 563/563 - 5s - loss: 6.3029e-04 - val_loss: 6.5888e-04 - 5s/epoch - 9ms/step
# Epoch 19/100
# 563/563 - 5s - loss: 6.2845e-04 - val_loss: 6.1682e-04 - 5s/epoch - 9ms/step
# Epoch 20/100
# 563/563 - 5s - loss: 6.2653e-04 - val_loss: 6.1512e-04 - 5s/epoch - 9ms/step
# Epoch 21/100
# 563/563 - 5s - loss: 6.1728e-04 - val_loss: 6.1915e-04 - 5s/epoch - 9ms/step
# Epoch 22/100
# 563/563 - 5s - loss: 6.1661e-04 - val_loss: 6.0630e-04 - 5s/epoch - 9ms/step
# Epoch 23/100
# 563/563 - 5s - loss: 6.1264e-04 - val_loss: 6.0093e-04 - 5s/epoch - 9ms/step
# Epoch 24/100
# 563/563 - 5s - loss: 6.1112e-04 - val_loss: 6.0521e-04 - 5s/epoch - 9ms/step
# Epoch 25/100
# 563/563 - 5s - loss: 6.0773e-04 - val_loss: 6.0736e-04 - 5s/epoch - 9ms/step
# Epoch 26/100
# 563/563 - 5s - loss: 5.9591e-04 - val_loss: 6.0110e-04 - 5s/epoch - 9ms/step
# Epoch 27/100
# 563/563 - 5s - loss: 6.1603e-04 - val_loss: 5.9581e-04 - 5s/epoch - 9ms/step
# Epoch 28/100
# 563/563 - 5s - loss: 5.9612e-04 - val_loss: 5.9595e-04 - 5s/epoch - 9ms/step
# Epoch 29/100
# 563/563 - 5s - loss: 5.9489e-04 - val_loss: 5.9136e-04 - 5s/epoch - 9ms/step
# Epoch 30/100
# 563/563 - 5s - loss: 5.9686e-04 - val_loss: 5.9123e-04 - 5s/epoch - 9ms/step
# Epoch 31/100
# 563/563 - 5s - loss: 5.9206e-04 - val_loss: 6.0392e-04 - 5s/epoch - 9ms/step
# Epoch 32/100
# 563/563 - 5s - loss: 5.8969e-04 - val_loss: 5.9081e-04 - 5s/epoch - 9ms/step
# Epoch 33/100
# 563/563 - 5s - loss: 5.8857e-04 - val_loss: 5.9334e-04 - 5s/epoch - 9ms/step
# Epoch 34/100
# 563/563 - 5s - loss: 5.8881e-04 - val_loss: 5.9153e-04 - 5s/epoch - 9ms/step
# Epoch 35/100
# 563/563 - 5s - loss: 5.8735e-04 - val_loss: 5.8545e-04 - 5s/epoch - 9ms/step
# Epoch 36/100
# 563/563 - 5s - loss: 5.8336e-04 - val_loss: 5.9508e-04 - 5s/epoch - 9ms/step
# Epoch 37/100
# 563/563 - 5s - loss: 5.8469e-04 - val_loss: 5.8901e-04 - 5s/epoch - 9ms/step
# Epoch 38/100
# 563/563 - 5s - loss: 5.8622e-04 - val_loss: 5.8490e-04 - 5s/epoch - 9ms/step
# Epoch 39/100
# 563/563 - 5s - loss: 5.7864e-04 - val_loss: 5.9542e-04 - 5s/epoch - 9ms/step
# Epoch 40/100
# 563/563 - 5s - loss: 5.8010e-04 - val_loss: 5.7735e-04 - 5s/epoch - 9ms/step
# Epoch 41/100
# 563/563 - 5s - loss: 5.7684e-04 - val_loss: 5.8243e-04 - 5s/epoch - 9ms/step
# Epoch 42/100
# 563/563 - 5s - loss: 5.7624e-04 - val_loss: 5.7999e-04 - 5s/epoch - 9ms/step
# Epoch 43/100
# 563/563 - 5s - loss: 5.7961e-04 - val_loss: 5.7884e-04 - 5s/epoch - 9ms/step
# Epoch 44/100
# 563/563 - 5s - loss: 5.7548e-04 - val_loss: 5.7502e-04 - 5s/epoch - 9ms/step
# Epoch 45/100
# 563/563 - 5s - loss: 5.7072e-04 - val_loss: 5.7950e-04 - 5s/epoch - 9ms/step
# Epoch 46/100
# 563/563 - 5s - loss: 5.8169e-04 - val_loss: 5.7728e-04 - 5s/epoch - 9ms/step
# Epoch 47/100
# 563/563 - 5s - loss: 5.6828e-04 - val_loss: 5.6927e-04 - 5s/epoch - 9ms/step
# Epoch 48/100
# 563/563 - 5s - loss: 5.7542e-04 - val_loss: 5.8064e-04 - 5s/epoch - 9ms/step
# Epoch 49/100
# 563/563 - 5s - loss: 5.6873e-04 - val_loss: 5.8786e-04 - 5s/epoch - 9ms/step
# Epoch 50/100
# 563/563 - 5s - loss: 5.7582e-04 - val_loss: 5.8239e-04 - 5s/epoch - 9ms/step
# Epoch 51/100
# 563/563 - 5s - loss: 5.6501e-04 - val_loss: 5.7506e-04 - 5s/epoch - 9ms/step
# Epoch 52/100
# 563/563 - 5s - loss: 5.6880e-04 - val_loss: 5.7127e-04 - 5s/epoch - 9ms/step
# Epoch 53/100
# 563/563 - 5s - loss: 5.6484e-04 - val_loss: 6.0130e-04 - 5s/epoch - 9ms/step
# Epoch 54/100
# 563/563 - 5s - loss: 5.6882e-04 - val_loss: 5.6584e-04 - 5s/epoch - 9ms/step
# Epoch 55/100
# 563/563 - 5s - loss: 5.6987e-04 - val_loss: 5.7982e-04 - 5s/epoch - 9ms/step
# Epoch 56/100
# 563/563 - 5s - loss: 5.6514e-04 - val_loss: 6.3501e-04 - 5s/epoch - 9ms/step
# Epoch 57/100
# 563/563 - 5s - loss: 5.6328e-04 - val_loss: 5.9379e-04 - 5s/epoch - 9ms/step
# Epoch 58/100
# 563/563 - 5s - loss: 5.6143e-04 - val_loss: 5.6565e-04 - 5s/epoch - 9ms/step
# Epoch 59/100
# 563/563 - 5s - loss: 5.6520e-04 - val_loss: 6.0379e-04 - 5s/epoch - 9ms/step
# Epoch 60/100
# 563/563 - 5s - loss: 5.6050e-04 - val_loss: 5.6386e-04 - 5s/epoch - 9ms/step
# Epoch 61/100
# 563/563 - 5s - loss: 5.6688e-04 - val_loss: 5.6814e-04 - 5s/epoch - 9ms/step
# Epoch 62/100
# 563/563 - 5s - loss: 5.6259e-04 - val_loss: 5.7273e-04 - 5s/epoch - 9ms/step
# Epoch 63/100
# 563/563 - 5s - loss: 5.6171e-04 - val_loss: 5.7016e-04 - 5s/epoch - 9ms/step
# Epoch 64/100
# 563/563 - 5s - loss: 5.5899e-04 - val_loss: 5.6956e-04 - 5s/epoch - 9ms/step
# Epoch 65/100
# 563/563 - 5s - loss: 5.6049e-04 - val_loss: 5.6304e-04 - 5s/epoch - 9ms/step
# Epoch 66/100
# 563/563 - 5s - loss: 5.6224e-04 - val_loss: 5.7432e-04 - 5s/epoch - 9ms/step
# Epoch 67/100
# 563/563 - 5s - loss: 5.5674e-04 - val_loss: 5.6373e-04 - 5s/epoch - 9ms/step
# Epoch 68/100
# 563/563 - 5s - loss: 5.5928e-04 - val_loss: 5.6987e-04 - 5s/epoch - 9ms/step
# Epoch 69/100
# 563/563 - 5s - loss: 5.5573e-04 - val_loss: 5.6492e-04 - 5s/epoch - 9ms/step
# Epoch 70/100
# 563/563 - 5s - loss: 5.5771e-04 - val_loss: 5.7070e-04 - 5s/epoch - 9ms/step
# Epoch 71/100
# 563/563 - 5s - loss: 5.5553e-04 - val_loss: 5.6551e-04 - 5s/epoch - 9ms/step
# Epoch 72/100
# 563/563 - 5s - loss: 5.5735e-04 - val_loss: 5.6492e-04 - 5s/epoch - 9ms/step
# Epoch 73/100
# 563/563 - 5s - loss: 5.5768e-04 - val_loss: 5.9602e-04 - 5s/epoch - 9ms/step
# Epoch 74/100
# 563/563 - 5s - loss: 5.5717e-04 - val_loss: 5.6392e-04 - 5s/epoch - 9ms/step
# Epoch 75/100
# 563/563 - 5s - loss: 5.5448e-04 - val_loss: 6.0076e-04 - 5s/epoch - 9ms/step
# Epoch 76/100
# 563/563 - 5s - loss: 5.5450e-04 - val_loss: 5.7115e-04 - 5s/epoch - 9ms/step
# Epoch 77/100
# 563/563 - 5s - loss: 5.5366e-04 - val_loss: 5.7729e-04 - 5s/epoch - 9ms/step
# Epoch 78/100
# 563/563 - 5s - loss: 5.5741e-04 - val_loss: 5.6728e-04 - 5s/epoch - 9ms/step
# Epoch 79/100
# 563/563 - 5s - loss: 5.5275e-04 - val_loss: 5.6554e-04 - 5s/epoch - 9ms/step
# Epoch 80/100
# 563/563 - 5s - loss: 5.5314e-04 - val_loss: 5.6688e-04 - 5s/epoch - 9ms/step
# Epoch 81/100
# 563/563 - 5s - loss: 5.5388e-04 - val_loss: 5.7196e-04 - 5s/epoch - 9ms/step
# Epoch 82/100
# 563/563 - 5s - loss: 5.5118e-04 - val_loss: 5.6393e-04 - 5s/epoch - 9ms/step
# Epoch 83/100
# 563/563 - 5s - loss: 5.5079e-04 - val_loss: 5.6589e-04 - 5s/epoch - 9ms/step
# Epoch 84/100
# 563/563 - 5s - loss: 5.5110e-04 - val_loss: 5.6025e-04 - 5s/epoch - 9ms/step
# Epoch 85/100
# 563/563 - 5s - loss: 5.5033e-04 - val_loss: 5.5958e-04 - 5s/epoch - 9ms/step
# Epoch 86/100
# 563/563 - 5s - loss: 5.5112e-04 - val_loss: 5.6404e-04 - 5s/epoch - 9ms/step
# Epoch 87/100
# 563/563 - 5s - loss: 5.5136e-04 - val_loss: 5.5890e-04 - 5s/epoch - 9ms/step
# Epoch 88/100
# 563/563 - 5s - loss: 5.5287e-04 - val_loss: 5.6571e-04 - 5s/epoch - 9ms/step
# Epoch 89/100
# 563/563 - 5s - loss: 5.4810e-04 - val_loss: 5.6120e-04 - 5s/epoch - 9ms/step
# Epoch 90/100
# 563/563 - 5s - loss: 5.5013e-04 - val_loss: 5.7711e-04 - 5s/epoch - 9ms/step
# Epoch 91/100
# 563/563 - 5s - loss: 5.4924e-04 - val_loss: 5.6049e-04 - 5s/epoch - 9ms/step
# Epoch 92/100
# 563/563 - 5s - loss: 5.4839e-04 - val_loss: 5.6019e-04 - 5s/epoch - 9ms/step
# Epoch 93/100
# 563/563 - 5s - loss: 5.5281e-04 - val_loss: 5.7093e-04 - 5s/epoch - 9ms/step
# Epoch 94/100
# 563/563 - 5s - loss: 5.4681e-04 - val_loss: 5.7369e-04 - 5s/epoch - 9ms/step
# Epoch 95/100
# 563/563 - 5s - loss: 5.4840e-04 - val_loss: 5.7062e-04 - 5s/epoch - 9ms/step
# Epoch 96/100
# 563/563 - 5s - loss: 5.5027e-04 - val_loss: 5.5795e-04 - 5s/epoch - 9ms/step
# Epoch 97/100
# 563/563 - 5s - loss: 5.4797e-04 - val_loss: 5.8083e-04 - 5s/epoch - 9ms/step
# Epoch 98/100
# 563/563 - 5s - loss: 5.4851e-04 - val_loss: 5.5804e-04 - 5s/epoch - 9ms/step
# Epoch 99/100
# 563/563 - 5s - loss: 5.4526e-04 - val_loss: 5.5819e-04 - 5s/epoch - 9ms/step
# Epoch 100/100
# 563/563 - 5s - loss: 5.5397e-04 - val_loss: 5.5838e-04 - 5s/epoch - 9ms/step

# %%
start = time.time()
cae_x_test_sp_noisy = autoencoder_sp.predict(x_test_cae_sp_noisy)
print(cae_x_test_sp_noisy.shape)
end = time.time()
Caetime= end - start
print("CPU 시간 : "+str(Caetime))
cae_x_test_sp_noisy = cae_x_test_sp_noisy.reshape(1267, 128, 128)
# Out:
# 40/40 [==============================] - 0s 8ms/step
# (1267, 128, 128, 1)
# CPU 시간 : 0.5155041217803955

# %%
ax = plt.subplot()
plt.imshow(cae_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Improved CAEfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
cae_loss = autoencodersp_train.history['loss']
cae_val_loss = autoencodersp_train.history['val_loss']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")
plt.plot(epochs, cae_val_loss, 'g', label="test")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
from skimage.metrics import structural_similarity as ssim

# %%
psnr_mean = []
mae_mean = []
psnr_median = []
mae_median = []
mae_lee = []
psnr_lee = []
psnr_cae = []
mae_cae = []

ssim_mean=[]
ssim_median=[]
ssim_lee=[]
ssim_cae=[]

for i in range(len(x_test_sp_noisy)):
    mae_mean.append(MAE(mean_x_test_sp_noisy[i],x_test[i]))
    mae_median.append(MAE(median_x_test_sp_noisy[i],x_test[i]))
    mae_lee.append(MAE(lee_x_test_sp_noisy[i],x_test[i]))
    mae_cae.append(MAE(cae_x_test_sp_noisy[i],x_test[i]))
    #print(cae_x_test_sp_noisy[i].shape)
    #print(x_test[i].shape)
    psnr_mean.append(PSNR(mean_x_test_sp_noisy[i],x_test[i]))
    psnr_median.append(PSNR(median_x_test_sp_noisy[i],x_test[i]))
    psnr_lee.append(PSNR(lee_x_test_sp_noisy[i],x_test[i]))
    psnr_cae.append(PSNR(cae_x_test_sp_noisy[i],x_test[i]))
    ssim_mean.append(ssim(x_test[i], mean_x_test_sp_noisy[i]))#,data_range=mean_x_test_sp_noisy[i].max() - mean_x_test_sp_noisy[i].min()))
    ssim_median.append(ssim(x_test[i], median_x_test_sp_noisy[i]))#,data_range=median_x_test_sp_noisy[i].max() - median_x_test_sp_noisy[i].min()))
    ssim_lee.append(ssim(x_test[i], lee_x_test_sp_noisy[i]))#,data_range=lee_x_test_sp_noisy[i].max() - lee_x_test_sp_noisy[i].min()))
    
    
    ssim_cae.append(ssim(x_test[i], cae_x_test_sp_noisy[i]))#,data_range=cae_x_test_sp_noisy[i].max() - cae_x_test_sp_noisy[i].min()))

# %%
print("About Gauss Noisy")
print("Mean Filter : MAE = " +  str(np.mean(mae_mean)) + " & PSNR = " + str(np.mean(psnr_mean))+" & SSIM = "+str(np.mean(ssim_mean)))
print("Median Filter : MAE = " +  str(np.mean(mae_median)) + " & PSNR = " + str(np.mean(psnr_median))+" & SSIM = "+str(np.mean(ssim_median)))
print("LEE Filter : MAE = " +  str(np.mean(mae_lee)) + " & PSNR = " + str(np.mean(psnr_lee))+" & SSIM = "+str(np.mean(ssim_lee)))
print("Improved CAE Filter : MAE = " +  str(np.mean(mae_cae)) + " & PSNR = " + str(np.mean(psnr_cae))+" & SSIM = "+str(np.mean(ssim_cae)))
# Out:
# About Gauss Noisy
# Mean Filter : MAE = 0.029839372540344564 & PSNR = 28.23858780470013 & SSIM = 0.8421985755545126
# Median Filter : MAE = 0.0356672974657613 & PSNR = 26.701203790682403 & SSIM = 0.7863096804431948
# LEE Filter : MAE = 0.030119662884712153 & PSNR = 28.32030584697837 & SSIM = 0.8328057156526094
# Improved CAE Filter : MAE = 0.017048920433234617 & PSNR = 32.78520228159062 & SSIM = 0.9472452330840961

# %%
# from skimage.util import random_noise

# %%
# a=ssim(x_test[1], x_test[1],data_range=1.0)#,data_range=x_test[1].max() - x_test[1].min())
# print(a)
