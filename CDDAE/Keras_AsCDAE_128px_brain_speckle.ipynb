# %%
# 필요 모델 호출
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import time
import random

# %%
def seed_everything(seed: int = 2022):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
class config:
    seed = 2022

# %%
seed_everything(config.seed)

# %%
# 이미지 로드
imglist = os.listdir('/Users/User/303/1_eonseung/AutoEncoder/Brain_data/Training/glioma/')
def load_image(path):
    image_list = np.zeros((len(imglist), 128, 128))
    for i in range(len(imglist)):
        img = Image.open('/Users/User/303/1_eonseung/AutoEncoder/Brain_data/Training/glioma/'+str(imglist[i])).convert('L')
        image_list[i] = img
    return image_list

# %%
posi = load_image('glioma/*.jpg')
posi = posi.astype('float32')/255.
print(posi.shape)
# Out:
# (5711, 128, 128)

# %%
def train_test_split(img):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(img))
    train_idx = perm[:int(0.8 * len(img))]
    test_idx = perm[int(0.8 * len(img)):]
    return img[train_idx], img[test_idx]

x_train, x_test = train_test_split(posi)
print(x_train.shape, x_test.shape)
# Out:
# (4568, 128, 128) (1143, 128, 128)

# %%
def noisy(noise_typ,image):
    #Gaussian Noisy
    if noise_typ == "gauss":
        
        noisy = image + 0.1 *  np.random.normal(loc=0,scale=1.,size=image.shape)
        return noisy
    #Salt & Pepper Noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 0.05
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
        out[tuple(coords)] = 1
        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[tuple(coords)] = 0
        return out

    # Speckle Noisy
    elif noise_typ =="speckle":
        noisy = np.random.normal(loc=0,scale=1.,size=image.shape)
        noisy = image+ image * 0.1 *noisy
        return noisy

# %%
def MAE(img1, img2):
    D = np.array(img1 - img2, dtype=np.float64)
    D[:, :] = np.abs(D[:, :])
    MAE = D.sum()/img1.size
    return MAE

def PSNR(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 1.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
from skimage.restoration import denoise_nl_means
from scipy.signal import medfilt2d
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance

def Meanfilter(noisy_test_data):
    meanfilter = []
    for i in range(len(noisy_test_data)):
         meanfilter.append(cv2.blur(noisy_test_data[i],(3,3)))
    meanfilter = np.array(meanfilter)
    return meanfilter
    
def Medianfilter(noisy_test_data):
    medianfilter = []
    for i in range(len(noisy_test_data)):
        medianfilter.append(medfilt2d(noisy_test_data[i],(3,3)))
    medianfilter = np.array(medianfilter)
    return medianfilter


def lee_filter(img):
    lee = []
    for i in range(len(img)):
        img_mean = uniform_filter(img[i])
        img_sqr_mean = uniform_filter(img[i]**2)
        img_variance = img_sqr_mean - img_mean**2
        
        overall_variance = variance(img[i])
        
        img_weights = (img_variance**2) / ((img_variance**2) + (overall_variance**2))
        img_output = img_mean + img_weights * (img[i] - img_mean)
        
        lee.append(img_output)
    lee = np.array(lee)
    return lee

# %%
# Add Noisy
x_train_sp_noisy = noisy("speckle",x_train)
x_test_sp_noisy = noisy("speckle",x_test)

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# Salt & Pepper Noisy Image
ax = plt.subplot()
plt.imshow(x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(speckle Noisy Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# MeanFilter Image
start = time.time()
mean_x_test_sp_noisy = Meanfilter(x_test_sp_noisy)
end = time.time()
Meantime= end - start
print("CPU 시간 : "+str(Meantime))

ax = plt.subplot()
plt.imshow(mean_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(speckle Noisy Meanfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.10935020446777344

# %%
# MedianFilter Image
start = time.time()
median_x_test_sp_noisy = Medianfilter(x_test_sp_noisy)
end = time.time()
Mediantime= end - start
print("CPU 시간 : "+str(Mediantime))

ax = plt.subplot()
plt.imshow(median_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(speckle Noisy Medianfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 1.2184650897979736

# %%
# LeeFilter Image
start = time.time()
lee_x_test_sp_noisy = lee_filter(x_test_sp_noisy)
end = time.time()
Leetime= end - start
print("CPU 시간 : "+str(Leetime))

ax = plt.subplot()
plt.imshow(lee_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Gauss Noisy lee_filter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.4686145782470703

# %%
#Convolution Neural Networks Filter Image
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, UpSampling2D
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D,Concatenate ,Conv2DTranspose
from keras import optimizers
from keras.models import Model
from keras import backend as K

# %%
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D ,LeakyReLU,ReLU, Concatenate
from keras import optimizers
from keras.models import Model

# %%
epochs = 100
inChannel = 1
x, y = 128, 128
input_img = Input(shape=(x,y,inChannel))

# %%
act=LeakyReLU(alpha=0.01)
#act = ReLU()

# %%
# Encoder

conv1 = Conv2D(16, (3,3), activation=act, padding='same',name='encoder1_cov')(input_img) 
pool1 = MaxPooling2D(pool_size=(2,2),name='maxpool1')(conv1) 
conv2 = Conv2D(32, (3,3), activation=act, padding='same',name='encoder2_cov')(pool1)
pool2 = MaxPooling2D(pool_size=(2,2),name='maxpool2')(conv2) 
encoded = Conv2D(64, (3,3), activation=act, padding='same',name='encoder3_cov')(pool2) 

# Decoder1
conv4 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder1_cov')(encoded)
up1 = UpSampling2D((2,2),name='up1')(conv4)
conv5 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder2_cov')(up1)
up2 = UpSampling2D((2,2),name='up2')(conv5)

# Decoder2
conv6 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder3_cov')(encoded)
up3 = UpSampling2D((2,2),name='up3')(conv6)
conv7 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder4_cov')(up3)
up4 = UpSampling2D((2,2),name='up4')(conv7)
#Merge
con=Concatenate()([up2,up4])
conv8 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder5_cov')(con)
decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same',name='result_cov')(conv8)

# %%
# CAEFilter Image
autoencoder_sp = Model(input_img, decoded)
autoencoder_sp.compile(loss='mean_squared_error',optimizer=optimizers.Adam())
autoencoder_sp.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  encoder1_cov (Conv2D)          (None, 128, 128, 16  160         ['input_2[0][0]']
#                                 )
#
#  maxpool1 (MaxPooling2D)        (None, 64, 64, 16)   0           ['encoder1_cov[0][0]']
#
#  encoder2_cov (Conv2D)          (None, 64, 64, 32)   4640        ['maxpool1[0][0]']
#
#  maxpool2 (MaxPooling2D)        (None, 32, 32, 32)   0           ['encoder2_cov[0][0]']
#
#  encoder3_cov (Conv2D)          (None, 32, 32, 64)   18496       ['maxpool2[0][0]']
#
#  decoder1_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  decoder3_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  up1 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder1_cov[0][0]']
#
#  up3 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder3_cov[0][0]']
#
#  decoder2_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up1[0][0]']
#
#  decoder4_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up3[0][0]']
#
#  up2 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder2_cov[0][0]']
#                                 )
#
#  up4 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder4_cov[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 64  0           ['up2[0][0]',
#                                 )                                 'up4[0][0]']
#
#  decoder5_cov (Conv2D)          (None, 128, 128, 64  36928       ['concatenate_1[0][0]']
#                                 )
#
#  result_cov (Conv2D)            (None, 128, 128, 1)  577         ['decoder5_cov[0][0]']
#
# ==================================================================================================
# Total params: 171,585
# Trainable params: 171,585
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train_cae = x_train.reshape(4568, 128, 128, 1)
x_test_cae = x_test.reshape(1143, 128, 128,1)
x_train_cae_sp_noisy = x_train_sp_noisy.reshape(4568, 128, 128, 1)
x_test_cae_sp_noisy = x_test_sp_noisy.reshape(1143, 128, 128,1)

# %%
autoencodersp_train = autoencoder_sp.fit(x_train_cae_sp_noisy, x_train_cae, 
                                    batch_size=9, 
                                    epochs=epochs, 
                                    verbose=2,
                                    validation_data=(x_test_cae_sp_noisy, x_test_cae))
# Out:
# Epoch 1/100
# 508/508 - 5s - loss: 0.0069 - val_loss: 0.0026 - 5s/epoch - 10ms/step
# Epoch 2/100
# 508/508 - 4s - loss: 0.0022 - val_loss: 0.0019 - 4s/epoch - 8ms/step
# Epoch 3/100
# 508/508 - 4s - loss: 0.0017 - val_loss: 0.0016 - 4s/epoch - 8ms/step
# Epoch 4/100
# 508/508 - 4s - loss: 0.0015 - val_loss: 0.0015 - 4s/epoch - 8ms/step
# Epoch 5/100
# 508/508 - 4s - loss: 0.0014 - val_loss: 0.0013 - 4s/epoch - 8ms/step
# Epoch 6/100
# 508/508 - 4s - loss: 0.0013 - val_loss: 0.0013 - 4s/epoch - 9ms/step
# Epoch 7/100
# 508/508 - 4s - loss: 0.0012 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 8/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0013 - 4s/epoch - 9ms/step
# Epoch 9/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0011 - 4s/epoch - 9ms/step
# Epoch 10/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0011 - 4s/epoch - 9ms/step
# Epoch 11/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 12/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 13/100
# 508/508 - 4s - loss: 9.9173e-04 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 14/100
# 508/508 - 4s - loss: 9.5478e-04 - val_loss: 0.0011 - 4s/epoch - 9ms/step
# Epoch 15/100
# 508/508 - 4s - loss: 9.4650e-04 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 16/100
# 508/508 - 5s - loss: 8.9580e-04 - val_loss: 9.6041e-04 - 5s/epoch - 9ms/step
# Epoch 17/100
# 508/508 - 5s - loss: 8.8833e-04 - val_loss: 9.2523e-04 - 5s/epoch - 9ms/step
# Epoch 18/100
# 508/508 - 5s - loss: 9.1386e-04 - val_loss: 9.2950e-04 - 5s/epoch - 9ms/step
# Epoch 19/100
# 508/508 - 5s - loss: 8.5222e-04 - val_loss: 9.0362e-04 - 5s/epoch - 9ms/step
# Epoch 20/100
# 508/508 - 5s - loss: 8.5689e-04 - val_loss: 8.7762e-04 - 5s/epoch - 9ms/step
# Epoch 21/100
# 508/508 - 5s - loss: 8.2907e-04 - val_loss: 8.7607e-04 - 5s/epoch - 9ms/step
# Epoch 22/100
# 508/508 - 5s - loss: 8.3958e-04 - val_loss: 8.8837e-04 - 5s/epoch - 9ms/step
# Epoch 23/100
# 508/508 - 5s - loss: 8.2535e-04 - val_loss: 8.5743e-04 - 5s/epoch - 9ms/step
# Epoch 24/100
# 508/508 - 5s - loss: 8.4096e-04 - val_loss: 8.5034e-04 - 5s/epoch - 9ms/step
# Epoch 25/100
# 508/508 - 5s - loss: 7.8825e-04 - val_loss: 8.3817e-04 - 5s/epoch - 9ms/step
# Epoch 26/100
# 508/508 - 5s - loss: 8.1406e-04 - val_loss: 8.3181e-04 - 5s/epoch - 9ms/step
# Epoch 27/100
# 508/508 - 5s - loss: 7.8470e-04 - val_loss: 8.3983e-04 - 5s/epoch - 9ms/step
# Epoch 28/100
# 508/508 - 5s - loss: 8.0182e-04 - val_loss: 8.7321e-04 - 5s/epoch - 9ms/step
# Epoch 29/100
# 508/508 - 5s - loss: 7.6414e-04 - val_loss: 9.0346e-04 - 5s/epoch - 9ms/step
# Epoch 30/100
# 508/508 - 5s - loss: 7.7815e-04 - val_loss: 8.3094e-04 - 5s/epoch - 9ms/step
# Epoch 31/100
# 508/508 - 5s - loss: 7.6765e-04 - val_loss: 7.9948e-04 - 5s/epoch - 9ms/step
# Epoch 32/100
# 508/508 - 5s - loss: 7.4757e-04 - val_loss: 7.9831e-04 - 5s/epoch - 9ms/step
# Epoch 33/100
# 508/508 - 5s - loss: 7.4095e-04 - val_loss: 8.0472e-04 - 5s/epoch - 9ms/step
# Epoch 34/100
# 508/508 - 5s - loss: 7.4305e-04 - val_loss: 8.6520e-04 - 5s/epoch - 9ms/step
# Epoch 35/100
# 508/508 - 5s - loss: 7.6980e-04 - val_loss: 7.8894e-04 - 5s/epoch - 9ms/step
# Epoch 36/100
# 508/508 - 5s - loss: 7.2343e-04 - val_loss: 9.3813e-04 - 5s/epoch - 9ms/step
# Epoch 37/100
# 508/508 - 5s - loss: 7.2215e-04 - val_loss: 7.7159e-04 - 5s/epoch - 9ms/step
# Epoch 38/100
# 508/508 - 5s - loss: 7.3117e-04 - val_loss: 7.8161e-04 - 5s/epoch - 9ms/step
# Epoch 39/100
# 508/508 - 5s - loss: 7.5418e-04 - val_loss: 9.0729e-04 - 5s/epoch - 9ms/step
# Epoch 40/100
# 508/508 - 5s - loss: 7.1138e-04 - val_loss: 7.7101e-04 - 5s/epoch - 9ms/step
# Epoch 41/100
# 508/508 - 5s - loss: 7.7825e-04 - val_loss: 7.6247e-04 - 5s/epoch - 9ms/step
# Epoch 42/100
# 508/508 - 5s - loss: 7.1071e-04 - val_loss: 7.8267e-04 - 5s/epoch - 9ms/step
# Epoch 43/100
# 508/508 - 5s - loss: 6.9821e-04 - val_loss: 7.4974e-04 - 5s/epoch - 9ms/step
# Epoch 44/100
# 508/508 - 5s - loss: 7.0887e-04 - val_loss: 7.8963e-04 - 5s/epoch - 9ms/step
# Epoch 45/100
# 508/508 - 5s - loss: 6.9779e-04 - val_loss: 7.4922e-04 - 5s/epoch - 9ms/step
# Epoch 46/100
# 508/508 - 5s - loss: 7.1174e-04 - val_loss: 7.8418e-04 - 5s/epoch - 9ms/step
# Epoch 47/100
# 508/508 - 5s - loss: 7.0329e-04 - val_loss: 7.3873e-04 - 5s/epoch - 9ms/step
# Epoch 48/100
# 508/508 - 5s - loss: 6.9843e-04 - val_loss: 8.0206e-04 - 5s/epoch - 9ms/step
# Epoch 49/100
# 508/508 - 5s - loss: 6.9375e-04 - val_loss: 7.4323e-04 - 5s/epoch - 9ms/step
# Epoch 50/100
# 508/508 - 5s - loss: 6.9245e-04 - val_loss: 7.4049e-04 - 5s/epoch - 9ms/step
# Epoch 51/100
# 508/508 - 5s - loss: 6.8545e-04 - val_loss: 7.7836e-04 - 5s/epoch - 9ms/step
# Epoch 52/100
# 508/508 - 5s - loss: 6.7928e-04 - val_loss: 7.6326e-04 - 5s/epoch - 9ms/step
# Epoch 53/100
# 508/508 - 5s - loss: 6.9567e-04 - val_loss: 7.2608e-04 - 5s/epoch - 9ms/step
# Epoch 54/100
# 508/508 - 5s - loss: 6.7082e-04 - val_loss: 7.9501e-04 - 5s/epoch - 9ms/step
# Epoch 55/100
# 508/508 - 6s - loss: 6.9399e-04 - val_loss: 7.3871e-04 - 6s/epoch - 12ms/step
# Epoch 56/100
# 508/508 - 5s - loss: 6.6986e-04 - val_loss: 7.2311e-04 - 5s/epoch - 9ms/step
# Epoch 57/100
# 508/508 - 5s - loss: 6.8304e-04 - val_loss: 8.0639e-04 - 5s/epoch - 9ms/step
# Epoch 58/100
# 508/508 - 5s - loss: 6.8270e-04 - val_loss: 7.2658e-04 - 5s/epoch - 9ms/step
# Epoch 59/100
# 508/508 - 5s - loss: 6.6831e-04 - val_loss: 9.0796e-04 - 5s/epoch - 9ms/step
# Epoch 60/100
# 508/508 - 5s - loss: 6.8513e-04 - val_loss: 7.2520e-04 - 5s/epoch - 9ms/step
# Epoch 61/100
# 508/508 - 5s - loss: 6.5981e-04 - val_loss: 7.1168e-04 - 5s/epoch - 9ms/step
# Epoch 62/100
# 508/508 - 5s - loss: 6.6493e-04 - val_loss: 7.1714e-04 - 5s/epoch - 9ms/step
# Epoch 63/100
# 508/508 - 5s - loss: 6.7567e-04 - val_loss: 7.1441e-04 - 5s/epoch - 9ms/step
# Epoch 64/100
# 508/508 - 5s - loss: 6.6733e-04 - val_loss: 7.1092e-04 - 5s/epoch - 9ms/step
# Epoch 65/100
# 508/508 - 5s - loss: 6.5731e-04 - val_loss: 7.0266e-04 - 5s/epoch - 9ms/step
# Epoch 66/100
# 508/508 - 5s - loss: 6.5520e-04 - val_loss: 7.3438e-04 - 5s/epoch - 9ms/step
# Epoch 67/100
# 508/508 - 5s - loss: 6.6138e-04 - val_loss: 7.1243e-04 - 5s/epoch - 9ms/step
# Epoch 68/100
# 508/508 - 5s - loss: 6.5662e-04 - val_loss: 6.9891e-04 - 5s/epoch - 9ms/step
# Epoch 69/100
# 508/508 - 5s - loss: 6.4608e-04 - val_loss: 7.0719e-04 - 5s/epoch - 9ms/step
# Epoch 70/100
# 508/508 - 5s - loss: 6.5452e-04 - val_loss: 7.5317e-04 - 5s/epoch - 9ms/step
# Epoch 71/100
# 508/508 - 5s - loss: 6.6950e-04 - val_loss: 7.1662e-04 - 5s/epoch - 9ms/step
# Epoch 72/100
# 508/508 - 5s - loss: 6.3830e-04 - val_loss: 7.0353e-04 - 5s/epoch - 9ms/step
# Epoch 73/100
# 508/508 - 5s - loss: 6.4888e-04 - val_loss: 7.2202e-04 - 5s/epoch - 9ms/step
# Epoch 74/100
# 508/508 - 5s - loss: 6.4914e-04 - val_loss: 7.2392e-04 - 5s/epoch - 9ms/step
# Epoch 75/100
# 508/508 - 5s - loss: 6.6360e-04 - val_loss: 8.4000e-04 - 5s/epoch - 9ms/step
# Epoch 76/100
# 508/508 - 5s - loss: 6.4574e-04 - val_loss: 6.9702e-04 - 5s/epoch - 9ms/step
# Epoch 77/100
# 508/508 - 5s - loss: 6.4303e-04 - val_loss: 7.0313e-04 - 5s/epoch - 9ms/step
# Epoch 78/100
# 508/508 - 5s - loss: 6.4299e-04 - val_loss: 6.8673e-04 - 5s/epoch - 9ms/step
# Epoch 79/100
# 508/508 - 5s - loss: 6.4758e-04 - val_loss: 7.2328e-04 - 5s/epoch - 9ms/step
# Epoch 80/100
# 508/508 - 5s - loss: 6.5834e-04 - val_loss: 7.6389e-04 - 5s/epoch - 9ms/step
# Epoch 81/100
# 508/508 - 5s - loss: 6.3263e-04 - val_loss: 6.8538e-04 - 5s/epoch - 9ms/step
# Epoch 82/100
# 508/508 - 5s - loss: 6.3758e-04 - val_loss: 7.1151e-04 - 5s/epoch - 9ms/step
# Epoch 83/100
# 508/508 - 5s - loss: 7.6325e-04 - val_loss: 7.3281e-04 - 5s/epoch - 9ms/step
# Epoch 84/100
# 508/508 - 5s - loss: 6.4264e-04 - val_loss: 7.2272e-04 - 5s/epoch - 9ms/step
# Epoch 85/100
# 508/508 - 5s - loss: 6.4097e-04 - val_loss: 6.8902e-04 - 5s/epoch - 9ms/step
# Epoch 86/100
# 508/508 - 5s - loss: 6.3369e-04 - val_loss: 6.8660e-04 - 5s/epoch - 9ms/step
# Epoch 87/100
# 508/508 - 5s - loss: 6.4165e-04 - val_loss: 6.8205e-04 - 5s/epoch - 9ms/step
# Epoch 88/100
# 508/508 - 5s - loss: 6.3621e-04 - val_loss: 7.0475e-04 - 5s/epoch - 9ms/step
# Epoch 89/100
# 508/508 - 5s - loss: 6.4510e-04 - val_loss: 7.2128e-04 - 5s/epoch - 9ms/step
# Epoch 90/100
# 508/508 - 5s - loss: 6.4675e-04 - val_loss: 6.9854e-04 - 5s/epoch - 9ms/step
# Epoch 91/100
# 508/508 - 5s - loss: 6.2816e-04 - val_loss: 7.1480e-04 - 5s/epoch - 9ms/step
# Epoch 92/100
# 508/508 - 5s - loss: 6.3627e-04 - val_loss: 6.9602e-04 - 5s/epoch - 9ms/step
# Epoch 93/100
# 508/508 - 5s - loss: 6.3785e-04 - val_loss: 6.8161e-04 - 5s/epoch - 9ms/step
# Epoch 94/100
# 508/508 - 5s - loss: 6.2733e-04 - val_loss: 8.1078e-04 - 5s/epoch - 9ms/step
# Epoch 95/100
# 508/508 - 5s - loss: 6.4187e-04 - val_loss: 6.8599e-04 - 5s/epoch - 9ms/step
# Epoch 96/100
# 508/508 - 5s - loss: 6.3022e-04 - val_loss: 6.7702e-04 - 5s/epoch - 9ms/step
# Epoch 97/100
# 508/508 - 5s - loss: 6.4901e-04 - val_loss: 6.8016e-04 - 5s/epoch - 9ms/step
# Epoch 98/100
# 508/508 - 5s - loss: 6.2909e-04 - val_loss: 6.9789e-04 - 5s/epoch - 9ms/step
# Epoch 99/100
# 508/508 - 5s - loss: 6.4206e-04 - val_loss: 6.9405e-04 - 5s/epoch - 9ms/step
# Epoch 100/100
# 508/508 - 5s - loss: 6.1849e-04 - val_loss: 7.0781e-04 - 5s/epoch - 9ms/step

# %%
start = time.time()
cae_x_test_sp_noisy = autoencoder_sp.predict(x_test_cae_sp_noisy)
print(cae_x_test_sp_noisy.shape)
end = time.time()
Caetime= end - start
print("CPU 시간 : "+str(Caetime))
cae_x_test_sp_noisy = cae_x_test_sp_noisy.reshape(1143, 128, 128)
# Out:
# 36/36 [==============================] - 1s 11ms/step
# (1143, 128, 128, 1)
# CPU 시간 : 0.7514309883117676

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
ax = plt.subplot()
plt.imshow(cae_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Imporved CAEfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
cae_loss = autoencodersp_train.history['loss']
cae_val_loss = autoencodersp_train.history['val_loss']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")
plt.plot(epochs, cae_val_loss, 'g', label="test")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
from skimage.metrics import structural_similarity as ssim

# %%
psnr_mean = []
mae_mean = []
psnr_median = []
mae_median = []
mae_lee = []
psnr_lee = []
psnr_cae = []
mae_cae = []

ssim_mean=[]
ssim_median=[]
ssim_lee=[]
ssim_cae=[]
for i in range(len(x_test_sp_noisy)):
    mae_mean.append(MAE(mean_x_test_sp_noisy[i],x_test[i]))
    mae_median.append(MAE(median_x_test_sp_noisy[i],x_test[i]))
    mae_lee.append(MAE(lee_x_test_sp_noisy[i],x_test[i]))
    mae_cae.append(MAE(cae_x_test_sp_noisy[i],x_test[i]))
    #print(cae_x_test_sp_noisy[i].shape)
    #print(x_test[i].shape)
    psnr_mean.append(PSNR(mean_x_test_sp_noisy[i],x_test[i]))
    psnr_median.append(PSNR(median_x_test_sp_noisy[i],x_test[i]))
    psnr_lee.append(PSNR(lee_x_test_sp_noisy[i],x_test[i]))
    psnr_cae.append(PSNR(cae_x_test_sp_noisy[i],x_test[i]))

    ssim_mean.append(ssim(x_test[i], mean_x_test_sp_noisy[i]))#,data_range=mean_x_test_sp_noisy[i].max() - mean_x_test_sp_noisy[i].min()))
    ssim_median.append(ssim(x_test[i], median_x_test_sp_noisy[i]))#,data_range=median_x_test_sp_noisy[i].max() - median_x_test_sp_noisy[i].min()))
    ssim_lee.append(ssim(x_test[i], lee_x_test_sp_noisy[i]))#,data_range=lee_x_test_sp_noisy[i].max() - lee_x_test_sp_noisy[i].min()))
    ssim_cae.append(ssim(x_test[i], cae_x_test_sp_noisy[i]))#,data_range=cae_x_test_sp_noisy[i].max() - cae_x_test_sp_noisy[i].min()))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\skimage\_shared\utils.py:348: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)

# %%
print("About Speckle Noisy")
print("Mean Filter : MAE = " +  str(np.mean(mae_mean)) + " & PSNR = " + str(np.mean(psnr_mean))+" & SSIM = "+str(np.mean(ssim_mean)))
print("Median Filter : MAE = " +  str(np.mean(mae_median)) + " & PSNR = " + str(np.mean(psnr_median))+" & SSIM = "+str(np.mean(ssim_median)))
print("LEE Filter : MAE = " +  str(np.mean(mae_lee)) + " & PSNR = " + str(np.mean(psnr_lee))+" & SSIM = "+str(np.mean(ssim_lee)))
print("ImprovedCDAE Filter : MAE = " +  str(np.mean(mae_cae)) + " & PSNR = " + str(np.mean(psnr_cae))+" & SSIM = "+str(np.mean(ssim_cae)))
# Out:
# About Speckle Noisy
# Mean Filter : MAE = 0.024138955963234583 & PSNR = 27.71419501006313 & SSIM = 0.9209434070022956
# Median Filter : MAE = 0.01977824766045575 & PSNR = 28.895810158510265 & SSIM = 0.9329941912495188
# LEE Filter : MAE = 0.019197867848144326 & PSNR = 30.31861705034423 & SSIM = 0.9445082349486419
# ImprovedCDAE Filter : MAE = 0.01499086914192657 & PSNR = 32.889926131932114 & SSIM = 0.9659399260260708

# %%
# 목표치s&p 31 gauss 29 speckle 32
