# %%
# 필요 모델 호출
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import time
import random

# %%
def seed_everything(seed: int = 2022):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
class config:
    seed = 2022

# %%
seed_everything(config.seed)

# %%
# 이미지 로드
imglist = os.listdir('/Users/User/303/1_eonseung/AutoEncoder/Brain_data/Training/glioma/')
def load_image(path):
    image_list = np.zeros((len(imglist), 128, 128))
    for i in range(len(imglist)):
        img = Image.open('/Users/User/303/1_eonseung/AutoEncoder/Brain_data/Training/glioma/'+str(imglist[i])).convert('L')
        image_list[i] = img
    return image_list

# %%
posi = load_image('glioma/*.jpg')
posi = posi.astype('float32')/255.
print(posi.shape)
# Out:
# (5711, 128, 128)

# %%
def train_test_split(img):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(img))
    train_idx = perm[:int(0.8 * len(img))]
    test_idx = perm[int(0.8 * len(img)):]
    return img[train_idx], img[test_idx]

x_train, x_test = train_test_split(posi)
print(x_train.shape, x_test.shape)
# Out:
# (4568, 128, 128) (1143, 128, 128)

# %%
def noisy(noise_typ,image):
    #Gaussian Noisy
    if noise_typ == "gauss":
        
        noisy = image + 0.1 *  np.random.normal(loc=0,scale=1.,size=image.shape)
        return noisy
    #Salt & Pepper Noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 0.05
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
        out[tuple(coords)] = 1
        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[tuple(coords)] = 0
        return out

    # Speckle Noisy
    elif noise_typ =="speckle":
        noisy = np.random.normal(loc=0,scale=1.,size=image.shape)
        noisy = image+ image * 0.1 *noisy
        return noisy

# %%
def MAE(img1, img2):
    D = np.array(img1 - img2, dtype=np.float64)
    D[:, :] = np.abs(D[:, :])
    MAE = D.sum()/img1.size
    return MAE

def PSNR(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 1.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
from skimage.restoration import denoise_nl_means
from scipy.signal import medfilt2d
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance

def Meanfilter(noisy_test_data):
    meanfilter = []
    for i in range(len(noisy_test_data)):
         meanfilter.append(cv2.blur(noisy_test_data[i],(3,3)))
    meanfilter = np.array(meanfilter)
    return meanfilter
    
def Medianfilter(noisy_test_data):
    medianfilter = []
    for i in range(len(noisy_test_data)):
        medianfilter.append(medfilt2d(noisy_test_data[i],(3,3)))
    medianfilter = np.array(medianfilter)
    return medianfilter


def lee_filter(img):
    lee = []
    for i in range(len(img)):
        img_mean = uniform_filter(img[i])
        img_sqr_mean = uniform_filter(img[i]**2)
        img_variance = img_sqr_mean - img_mean**2
        
        overall_variance = variance(img[i])
        
        img_weights = (img_variance**2) / ((img_variance**2) + (overall_variance**2))
        img_output = img_mean + img_weights * (img[i] - img_mean)
        
        lee.append(img_output)
    lee = np.array(lee)
    return lee

# %%
# Add Noisy
x_train_sp_noisy = noisy("s&p",x_train)
x_test_sp_noisy = noisy("s&p",x_test)

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# Salt & Pepper Noisy Image
ax = plt.subplot()
plt.imshow(x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(S&P Noisy Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# MeanFilter Image
start = time.time()
mean_x_test_sp_noisy = Meanfilter(x_test_sp_noisy)
end = time.time()
Meantime= end - start
print("CPU 시간 : "+str(Meantime))

ax = plt.subplot()
plt.imshow(mean_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(S&P Noisy Meanfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.09372830390930176

# %%
# MedianFilter Image
start = time.time()
median_x_test_sp_noisy = Medianfilter(x_test_sp_noisy)
end = time.time()
Mediantime= end - start
print("CPU 시간 : "+str(Mediantime))

ax = plt.subplot()
plt.imshow(median_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(S&P Noisy Medianfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 1.093492031097412

# %%
# LeeFilter Image
start = time.time()
lee_x_test_sp_noisy = lee_filter(x_test_sp_noisy)
end = time.time()
Leetime= end - start
print("CPU 시간 : "+str(Leetime))

ax = plt.subplot()
plt.imshow(lee_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(S&P Noisy lee_filter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.3436696529388428

# %%
#Convolution Neural Networks Filter Image
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, UpSampling2D
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D,Concatenate ,Conv2DTranspose
from keras import optimizers
from keras.models import Model
from keras import backend as K

# %%
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D ,LeakyReLU,ReLU, Concatenate
from keras import optimizers
from keras.models import Model

# %%
epochs = 100
inChannel = 1
x, y = 128, 128
input_img = Input(shape=(x,y,inChannel))

# %%
act=LeakyReLU(alpha=0.01)
#act = ReLU()

# %%
# Encoder

conv1 = Conv2D(16, (3,3), activation=act, padding='same',name='encoder1_cov')(input_img) 
pool1 = MaxPooling2D(pool_size=(2,2),name='maxpool1')(conv1) 
conv2 = Conv2D(32, (3,3), activation=act, padding='same',name='encoder2_cov')(pool1)
pool2 = MaxPooling2D(pool_size=(2,2),name='maxpool2')(conv2) 
encoded = Conv2D(64, (3,3), activation=act, padding='same',name='encoder3_cov')(pool2) 

# Decoder1
conv4 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder1_cov')(encoded)
up1 = UpSampling2D((2,2),name='up1')(conv4)
conv5 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder2_cov')(up1)
up2 = UpSampling2D((2,2),name='up2')(conv5)

# Decoder2
conv6 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder3_cov')(encoded)
up3 = UpSampling2D((2,2),name='up3')(conv6)
conv7 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder4_cov')(up3)
up4 = UpSampling2D((2,2),name='up4')(conv7)
#Merge
con=Concatenate()([up2,up4])
conv8 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder5_cov')(con)
decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same',name='result_cov')(conv8)

# %%
# CAEFilter Image
autoencoder_sp = Model(input_img, decoded)
autoencoder_sp.compile(loss='mean_squared_error',optimizer=optimizers.Adam())
autoencoder_sp.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  encoder1_cov (Conv2D)          (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  maxpool1 (MaxPooling2D)        (None, 64, 64, 16)   0           ['encoder1_cov[0][0]']
#
#  encoder2_cov (Conv2D)          (None, 64, 64, 32)   4640        ['maxpool1[0][0]']
#
#  maxpool2 (MaxPooling2D)        (None, 32, 32, 32)   0           ['encoder2_cov[0][0]']
#
#  encoder3_cov (Conv2D)          (None, 32, 32, 64)   18496       ['maxpool2[0][0]']
#
#  decoder1_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  decoder3_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  up1 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder1_cov[0][0]']
#
#  up3 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder3_cov[0][0]']
#
#  decoder2_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up1[0][0]']
#
#  decoder4_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up3[0][0]']
#
#  up2 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder2_cov[0][0]']
#                                 )
#
#  up4 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder4_cov[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 128, 128, 64  0           ['up2[0][0]',
#                                 )                                 'up4[0][0]']
#
#  decoder5_cov (Conv2D)          (None, 128, 128, 64  36928       ['concatenate[0][0]']
#                                 )
#
#  result_cov (Conv2D)            (None, 128, 128, 1)  577         ['decoder5_cov[0][0]']
#
# ==================================================================================================
# Total params: 171,585
# Trainable params: 171,585
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train_cae = x_train.reshape(4568, 128, 128, 1)
x_test_cae = x_test.reshape(1143, 128, 128,1)
x_train_cae_sp_noisy = x_train_sp_noisy.reshape(4568, 128, 128, 1)
x_test_cae_sp_noisy = x_test_sp_noisy.reshape(1143, 128, 128,1)

# %%
autoencodersp_train = autoencoder_sp.fit(x_train_cae_sp_noisy, x_train_cae, 
                                    batch_size=9, 
                                    epochs=epochs, 
                                    verbose=2,
                                    validation_data=(x_test_cae_sp_noisy, x_test_cae))
# Out:
# Epoch 1/100
# 508/508 - 8s - loss: 0.0075 - val_loss: 0.0035 - 8s/epoch - 15ms/step
# Epoch 2/100
# 508/508 - 4s - loss: 0.0028 - val_loss: 0.0026 - 4s/epoch - 8ms/step
# Epoch 3/100
# 508/508 - 4s - loss: 0.0022 - val_loss: 0.0022 - 4s/epoch - 8ms/step
# Epoch 4/100
# 508/508 - 4s - loss: 0.0019 - val_loss: 0.0019 - 4s/epoch - 8ms/step
# Epoch 5/100
# 508/508 - 4s - loss: 0.0018 - val_loss: 0.0021 - 4s/epoch - 9ms/step
# Epoch 6/100
# 508/508 - 4s - loss: 0.0016 - val_loss: 0.0016 - 4s/epoch - 9ms/step
# Epoch 7/100
# 508/508 - 4s - loss: 0.0016 - val_loss: 0.0016 - 4s/epoch - 9ms/step
# Epoch 8/100
# 508/508 - 4s - loss: 0.0015 - val_loss: 0.0016 - 4s/epoch - 9ms/step
# Epoch 9/100
# 508/508 - 4s - loss: 0.0014 - val_loss: 0.0015 - 4s/epoch - 9ms/step
# Epoch 10/100
# 508/508 - 4s - loss: 0.0014 - val_loss: 0.0015 - 4s/epoch - 9ms/step
# Epoch 11/100
# 508/508 - 4s - loss: 0.0013 - val_loss: 0.0014 - 4s/epoch - 9ms/step
# Epoch 12/100
# 508/508 - 4s - loss: 0.0013 - val_loss: 0.0013 - 4s/epoch - 9ms/step
# Epoch 13/100
# 508/508 - 4s - loss: 0.0012 - val_loss: 0.0013 - 4s/epoch - 9ms/step
# Epoch 14/100
# 508/508 - 4s - loss: 0.0012 - val_loss: 0.0013 - 4s/epoch - 9ms/step
# Epoch 15/100
# 508/508 - 4s - loss: 0.0012 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 16/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 17/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 18/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 19/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 20/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 21/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 22/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0012 - 4s/epoch - 9ms/step
# Epoch 23/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0011 - 4s/epoch - 9ms/step
# Epoch 24/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0011 - 4s/epoch - 9ms/step
# Epoch 25/100
# 508/508 - 4s - loss: 9.6701e-04 - val_loss: 0.0011 - 4s/epoch - 9ms/step
# Epoch 26/100
# 508/508 - 4s - loss: 0.0011 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 27/100
# 508/508 - 4s - loss: 9.4831e-04 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 28/100
# 508/508 - 4s - loss: 0.0010 - val_loss: 0.0010 - 4s/epoch - 9ms/step
# Epoch 29/100
# 508/508 - 5s - loss: 9.4989e-04 - val_loss: 9.9127e-04 - 5s/epoch - 9ms/step
# Epoch 30/100
# 508/508 - 7s - loss: 9.4376e-04 - val_loss: 9.8609e-04 - 7s/epoch - 14ms/step
# Epoch 31/100
# 508/508 - 15s - loss: 9.1770e-04 - val_loss: 9.9148e-04 - 15s/epoch - 29ms/step
# Epoch 32/100
# 508/508 - 13s - loss: 9.1646e-04 - val_loss: 9.7653e-04 - 13s/epoch - 25ms/step
# Epoch 33/100
# 508/508 - 15s - loss: 9.1326e-04 - val_loss: 9.8860e-04 - 15s/epoch - 29ms/step
# Epoch 34/100
# 508/508 - 13s - loss: 8.9724e-04 - val_loss: 0.0010 - 13s/epoch - 26ms/step
# Epoch 35/100
# 508/508 - 13s - loss: 9.0366e-04 - val_loss: 9.7702e-04 - 13s/epoch - 25ms/step
# Epoch 36/100
# 508/508 - 15s - loss: 8.9262e-04 - val_loss: 9.5038e-04 - 15s/epoch - 29ms/step
# Epoch 37/100
# 508/508 - 13s - loss: 8.7786e-04 - val_loss: 9.5047e-04 - 13s/epoch - 25ms/step
# Epoch 38/100
# 508/508 - 14s - loss: 8.8192e-04 - val_loss: 9.3324e-04 - 14s/epoch - 28ms/step
# Epoch 39/100
# 508/508 - 14s - loss: 9.2402e-04 - val_loss: 9.3022e-04 - 14s/epoch - 28ms/step
# Epoch 40/100
# 508/508 - 12s - loss: 8.4560e-04 - val_loss: 9.2937e-04 - 12s/epoch - 25ms/step
# Epoch 41/100
# 508/508 - 14s - loss: 8.5215e-04 - val_loss: 9.9181e-04 - 14s/epoch - 28ms/step
# Epoch 42/100
# 508/508 - 11s - loss: 8.5572e-04 - val_loss: 9.1341e-04 - 11s/epoch - 21ms/step
# Epoch 43/100
# 508/508 - 5s - loss: 8.6687e-04 - val_loss: 9.3228e-04 - 5s/epoch - 9ms/step
# Epoch 44/100
# 508/508 - 5s - loss: 8.5121e-04 - val_loss: 9.2548e-04 - 5s/epoch - 9ms/step
# Epoch 45/100
# 508/508 - 4s - loss: 8.2953e-04 - val_loss: 9.2705e-04 - 4s/epoch - 9ms/step
# Epoch 46/100
# 508/508 - 4s - loss: 8.3445e-04 - val_loss: 8.9829e-04 - 4s/epoch - 9ms/step
# Epoch 47/100
# 508/508 - 5s - loss: 8.3854e-04 - val_loss: 9.1141e-04 - 5s/epoch - 9ms/step
# Epoch 48/100
# 508/508 - 5s - loss: 8.3190e-04 - val_loss: 9.0319e-04 - 5s/epoch - 9ms/step
# Epoch 49/100
# 508/508 - 5s - loss: 8.3613e-04 - val_loss: 9.1283e-04 - 5s/epoch - 9ms/step
# Epoch 50/100
# 508/508 - 5s - loss: 8.1821e-04 - val_loss: 9.0057e-04 - 5s/epoch - 9ms/step
# Epoch 51/100
# 508/508 - 5s - loss: 8.4390e-04 - val_loss: 8.7693e-04 - 5s/epoch - 9ms/step
# Epoch 52/100
# 508/508 - 5s - loss: 8.2130e-04 - val_loss: 8.8726e-04 - 5s/epoch - 9ms/step
# Epoch 53/100
# 508/508 - 5s - loss: 8.1176e-04 - val_loss: 8.7461e-04 - 5s/epoch - 9ms/step
# Epoch 54/100
# 508/508 - 5s - loss: 8.1449e-04 - val_loss: 0.0010 - 5s/epoch - 9ms/step
# Epoch 55/100
# 508/508 - 5s - loss: 8.0911e-04 - val_loss: 0.0011 - 5s/epoch - 9ms/step
# Epoch 56/100
# 508/508 - 5s - loss: 8.8167e-04 - val_loss: 9.2533e-04 - 5s/epoch - 9ms/step
# Epoch 57/100
# 508/508 - 5s - loss: 8.0379e-04 - val_loss: 8.6344e-04 - 5s/epoch - 9ms/step
# Epoch 58/100
# 508/508 - 5s - loss: 8.0215e-04 - val_loss: 8.8316e-04 - 5s/epoch - 9ms/step
# Epoch 59/100
# 508/508 - 5s - loss: 7.9253e-04 - val_loss: 9.5162e-04 - 5s/epoch - 9ms/step
# Epoch 60/100
# 508/508 - 5s - loss: 8.0121e-04 - val_loss: 8.6727e-04 - 5s/epoch - 9ms/step
# Epoch 61/100
# 508/508 - 5s - loss: 7.9963e-04 - val_loss: 8.6688e-04 - 5s/epoch - 9ms/step
# Epoch 62/100
# 508/508 - 5s - loss: 7.9527e-04 - val_loss: 8.6714e-04 - 5s/epoch - 9ms/step
# Epoch 63/100
# 508/508 - 5s - loss: 7.8812e-04 - val_loss: 9.1310e-04 - 5s/epoch - 9ms/step
# Epoch 64/100
# 508/508 - 5s - loss: 7.8703e-04 - val_loss: 8.4395e-04 - 5s/epoch - 9ms/step
# Epoch 65/100
# 508/508 - 5s - loss: 8.0469e-04 - val_loss: 8.9280e-04 - 5s/epoch - 9ms/step
# Epoch 66/100
# 508/508 - 5s - loss: 7.9802e-04 - val_loss: 8.7364e-04 - 5s/epoch - 9ms/step
# Epoch 67/100
# 508/508 - 5s - loss: 7.7045e-04 - val_loss: 8.4968e-04 - 5s/epoch - 9ms/step
# Epoch 68/100
# 508/508 - 5s - loss: 7.8610e-04 - val_loss: 8.6018e-04 - 5s/epoch - 9ms/step
# Epoch 69/100
# 508/508 - 5s - loss: 7.8508e-04 - val_loss: 9.4000e-04 - 5s/epoch - 9ms/step
# Epoch 70/100
# 508/508 - 5s - loss: 7.6888e-04 - val_loss: 8.5145e-04 - 5s/epoch - 9ms/step
# Epoch 71/100
# 508/508 - 5s - loss: 7.7220e-04 - val_loss: 9.6113e-04 - 5s/epoch - 9ms/step
# Epoch 72/100
# 508/508 - 5s - loss: 7.6893e-04 - val_loss: 8.5178e-04 - 5s/epoch - 9ms/step
# Epoch 73/100
# 508/508 - 5s - loss: 7.8420e-04 - val_loss: 8.3532e-04 - 5s/epoch - 9ms/step
# Epoch 74/100
# 508/508 - 5s - loss: 7.7998e-04 - val_loss: 8.5561e-04 - 5s/epoch - 9ms/step
# Epoch 75/100
# 508/508 - 5s - loss: 7.7283e-04 - val_loss: 8.5218e-04 - 5s/epoch - 9ms/step
# Epoch 76/100
# 508/508 - 5s - loss: 7.6812e-04 - val_loss: 8.4878e-04 - 5s/epoch - 9ms/step
# Epoch 77/100
# 508/508 - 5s - loss: 7.6640e-04 - val_loss: 8.3873e-04 - 5s/epoch - 9ms/step
# Epoch 78/100
# 508/508 - 5s - loss: 7.7370e-04 - val_loss: 8.5369e-04 - 5s/epoch - 9ms/step
# Epoch 79/100
# 508/508 - 5s - loss: 7.4909e-04 - val_loss: 8.2277e-04 - 5s/epoch - 9ms/step
# Epoch 80/100
# 508/508 - 5s - loss: 8.1409e-04 - val_loss: 9.1590e-04 - 5s/epoch - 9ms/step
# Epoch 81/100
# 508/508 - 5s - loss: 7.5738e-04 - val_loss: 9.3124e-04 - 5s/epoch - 9ms/step
# Epoch 82/100
# 508/508 - 5s - loss: 7.5437e-04 - val_loss: 0.0011 - 5s/epoch - 9ms/step
# Epoch 83/100
# 508/508 - 5s - loss: 7.6512e-04 - val_loss: 8.2888e-04 - 5s/epoch - 9ms/step
# Epoch 84/100
# 508/508 - 5s - loss: 7.5644e-04 - val_loss: 8.2817e-04 - 5s/epoch - 9ms/step
# Epoch 85/100
# 508/508 - 5s - loss: 7.4412e-04 - val_loss: 8.2835e-04 - 5s/epoch - 9ms/step
# Epoch 86/100
# 508/508 - 5s - loss: 7.5630e-04 - val_loss: 8.4729e-04 - 5s/epoch - 9ms/step
# Epoch 87/100
# 508/508 - 5s - loss: 7.4991e-04 - val_loss: 8.3862e-04 - 5s/epoch - 9ms/step
# Epoch 88/100
# 508/508 - 5s - loss: 7.4625e-04 - val_loss: 8.2183e-04 - 5s/epoch - 9ms/step
# Epoch 89/100
# 508/508 - 5s - loss: 7.5194e-04 - val_loss: 8.3914e-04 - 5s/epoch - 9ms/step
# Epoch 90/100
# 508/508 - 5s - loss: 7.3661e-04 - val_loss: 8.2058e-04 - 5s/epoch - 9ms/step
# Epoch 91/100
# 508/508 - 5s - loss: 7.5276e-04 - val_loss: 8.2723e-04 - 5s/epoch - 9ms/step
# Epoch 92/100
# 508/508 - 5s - loss: 7.5342e-04 - val_loss: 8.2768e-04 - 5s/epoch - 9ms/step
# Epoch 93/100
# 508/508 - 5s - loss: 7.3942e-04 - val_loss: 8.1098e-04 - 5s/epoch - 9ms/step
# Epoch 94/100
# 508/508 - 5s - loss: 7.5101e-04 - val_loss: 8.8106e-04 - 5s/epoch - 9ms/step
# Epoch 95/100
# 508/508 - 5s - loss: 7.3139e-04 - val_loss: 8.1460e-04 - 5s/epoch - 9ms/step
# Epoch 96/100
# 508/508 - 5s - loss: 7.4396e-04 - val_loss: 0.0011 - 5s/epoch - 9ms/step
# Epoch 97/100
# 508/508 - 5s - loss: 7.4949e-04 - val_loss: 8.2067e-04 - 5s/epoch - 9ms/step
# Epoch 98/100
# 508/508 - 5s - loss: 7.2984e-04 - val_loss: 8.5307e-04 - 5s/epoch - 9ms/step
# Epoch 99/100
# 508/508 - 5s - loss: 7.3875e-04 - val_loss: 8.3489e-04 - 5s/epoch - 9ms/step
# Epoch 100/100
# 508/508 - 5s - loss: 7.4531e-04 - val_loss: 8.2177e-04 - 5s/epoch - 9ms/step

# %%
start = time.time()
cae_x_test_sp_noisy = autoencoder_sp.predict(x_test_cae_sp_noisy)
print(cae_x_test_sp_noisy.shape)
end = time.time()
Caetime= end - start
print("CPU 시간 : "+str(Caetime))
cae_x_test_sp_noisy = cae_x_test_sp_noisy.reshape(1143, 128, 128)
# Out:
# 36/36 [==============================] - 1s 12ms/step
# (1143, 128, 128, 1)
# CPU 시간 : 0.8435451984405518

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
ax = plt.subplot()
plt.imshow(cae_x_test_sp_noisy[2], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Imporved CAEfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
cae_loss = autoencodersp_train.history['loss']
cae_val_loss = autoencodersp_train.history['val_loss']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")
plt.plot(epochs, cae_val_loss, 'g', label="test")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
from skimage.metrics import structural_similarity as ssim

# %%
psnr_mean = []
mae_mean = []
psnr_median = []
mae_median = []
mae_lee = []
psnr_lee = []
psnr_cae = []
mae_cae = []

ssim_mean=[]
ssim_median=[]
ssim_lee=[]
ssim_cae=[]
for i in range(len(x_test_sp_noisy)):
    mae_mean.append(MAE(mean_x_test_sp_noisy[i],x_test[i]))
    mae_median.append(MAE(median_x_test_sp_noisy[i],x_test[i]))
    mae_lee.append(MAE(lee_x_test_sp_noisy[i],x_test[i]))
    mae_cae.append(MAE(cae_x_test_sp_noisy[i],x_test[i]))
    #print(cae_x_test_sp_noisy[i].shape)
    #print(x_test[i].shape)
    psnr_mean.append(PSNR(mean_x_test_sp_noisy[i],x_test[i]))
    psnr_median.append(PSNR(median_x_test_sp_noisy[i],x_test[i]))
    psnr_lee.append(PSNR(lee_x_test_sp_noisy[i],x_test[i]))
    psnr_cae.append(PSNR(cae_x_test_sp_noisy[i],x_test[i]))

    ssim_mean.append(ssim(x_test[i], mean_x_test_sp_noisy[i]))#,data_range=mean_x_test_sp_noisy[i].max() - mean_x_test_sp_noisy[i].min()))
    ssim_median.append(ssim(x_test[i], median_x_test_sp_noisy[i]))#,data_range=median_x_test_sp_noisy[i].max() - median_x_test_sp_noisy[i].min()))
    ssim_lee.append(ssim(x_test[i], lee_x_test_sp_noisy[i]))#,data_range=lee_x_test_sp_noisy[i].max() - lee_x_test_sp_noisy[i].min()))
    ssim_cae.append(ssim(x_test[i], cae_x_test_sp_noisy[i]))#,data_range=cae_x_test_sp_noisy[i].max() - cae_x_test_sp_noisy[i].min()))

# %%
print("About S&P Noisy")
print("Mean Filter : MAE = " +  str(np.mean(mae_mean)) + " & PSNR = " + str(np.mean(psnr_mean))+" & SSIM = "+str(np.mean(ssim_mean)))
print("Median Filter : MAE = " +  str(np.mean(mae_median)) + " & PSNR = " + str(np.mean(psnr_median))+" & SSIM = "+str(np.mean(ssim_median)))
print("LEE Filter : MAE = " +  str(np.mean(mae_lee)) + " & PSNR = " + str(np.mean(psnr_lee))+" & SSIM = "+str(np.mean(ssim_lee)))
print("ImprovedCDAE Filter : MAE = " +  str(np.mean(mae_cae)) + " & PSNR = " + str(np.mean(psnr_cae))+" & SSIM = "+str(np.mean(ssim_cae)))
# Out:
# About S&P Noisy
# Mean Filter : MAE = 0.041057365020421246 & PSNR = 23.523605264581594 & SSIM = 0.6937954959595015
# Median Filter : MAE = 0.016533352767592404 & PSNR = 29.107888502398357 & SSIM = 0.940679599849051
# LEE Filter : MAE = 0.03771610308507874 & PSNR = 19.131659966808055 & SSIM = 0.5738519324289415
# ImprovedCDAE Filter : MAE = 0.015369595393852475 & PSNR = 32.40245767376112 & SSIM = 0.9632935070344879

# %%
# 목표치s&p 31 gauss 29 speckle 32
