# %%
# 필요 모델 호출
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import time
import random

# %%
def seed_everything(seed: int = 2022):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
class config:
    seed = 2022

# %%
seed_everything(config.seed)

# %%
# 이미지 로드
imglist = os.listdir('/Users/User/303/CDAE_chest128px/train/')
def load_image(path):
    image_list = np.zeros((len(imglist), 128, 128))
    for i in range(len(imglist)):
        img = Image.open('/Users/User/303/CDAE_chest128px/train/'+str(imglist[i])).convert('L')
        image_list[i] = img
    return image_list

# %%
posi = load_image('/Users/User/303/CDAE_chest128px/train/*.jpg')
posi = posi.astype('float32')/255.
print(posi.shape)
# Out:
# (6334, 128, 128)

# %%
def train_test_split(img):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(img))
    train_idx = perm[:int(0.8 * len(img))]
    test_idx = perm[int(0.8 * len(img)):]
    return img[train_idx], img[test_idx]

x_train, x_test = train_test_split(posi)
print(x_train.shape, x_test.shape)
# Out:
# (5067, 128, 128) (1267, 128, 128)

# %%
def noisy(noise_typ,image):
    #Gaussian Noisy
    if noise_typ == "gauss":
        
        noisy = image + 0.1 *  np.random.normal(loc=0,scale=1.,size=image.shape)
        return noisy
    #Salt & Pepper Noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 0.05
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
        out[tuple(coords)] = 1
        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[tuple(coords)] = 0
        return out

    # Speckle Noisy
    elif noise_typ =="speckle":
        noisy = np.random.normal(loc=0,scale=1.,size=image.shape)
        noisy = image+ image * 0.1 *noisy
        return noisy

# %%
def MAE(img1, img2):
    D = np.array(img1 - img2, dtype=np.float64)
    D[:, :] = np.abs(D[:, :])
    MAE = D.sum()/img1.size
    return MAE

def PSNR(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 1.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
from skimage.restoration import denoise_nl_means
from scipy.signal import medfilt2d
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance

def Meanfilter(noisy_test_data):
    meanfilter = []
    for i in range(len(noisy_test_data)):
         meanfilter.append(cv2.blur(noisy_test_data[i],(3,3)))
    meanfilter = np.array(meanfilter)
    return meanfilter
    
def Medianfilter(noisy_test_data):
    medianfilter = []
    for i in range(len(noisy_test_data)):
        medianfilter.append(medfilt2d(noisy_test_data[i],(3,3)))
    medianfilter = np.array(medianfilter)
    return medianfilter


def lee_filter(img):
    lee = []
    for i in range(len(img)):
        img_mean = uniform_filter(img[i])
        img_sqr_mean = uniform_filter(img[i]**2)
        img_variance = img_sqr_mean - img_mean**2
        
        overall_variance = variance(img[i])
        
        img_weights = (img_variance**2) / ((img_variance**2) + (overall_variance**2))
        img_output = img_mean + img_weights * (img[i] - img_mean)
        
        lee.append(img_output)
    lee = np.array(lee)
    return lee

# %%
# Add Noisy
x_train_sp_noisy = noisy("s&p",x_train)
x_test_sp_noisy = noisy("s&p",x_test)

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# Salt & Pepper Noisy Image
ax = plt.subplot()
plt.imshow(x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(s&p Noisy Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# MeanFilter Image
start = time.time()
mean_x_test_sp_noisy = Meanfilter(x_test_sp_noisy)
end = time.time()
Meantime= end - start
print("CPU 시간 : "+str(Meantime))

ax = plt.subplot()
plt.imshow(mean_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(s&p Noisy Meanfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.07813739776611328

# %%
# MedianFilter Image
start = time.time()
median_x_test_sp_noisy = Medianfilter(x_test_sp_noisy)
end = time.time()
Mediantime= end - start
print("CPU 시간 : "+str(Mediantime))

ax = plt.subplot()
plt.imshow(median_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(s&p Noisy Medianfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 1.109142780303955

# %%
# LeeFilter Image
start = time.time()
lee_x_test_sp_noisy = lee_filter(x_test_sp_noisy)
end = time.time()
Leetime= end - start
print("CPU 시간 : "+str(Leetime))

ax = plt.subplot()
plt.imshow(lee_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(s&p Noisy lee_filter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.3905622959136963

# %%
#Convolution Neural Networks Filter Image
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, UpSampling2D
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from keras import optimizers
from keras.models import Model

# %%
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D ,LeakyReLU,ReLU,Concatenate
from keras import optimizers
from keras.models import Model

# %%
epochs = 100
inChannel = 1
x, y = 128, 128
input_img = Input(shape=(x,y,inChannel))

# %%
act=LeakyReLU(alpha=0.01)
#act=ReLU()

# %%
# Encoder

conv1 = Conv2D(16, (3,3), activation=act, padding='same',name='encoder1_cov')(input_img) 
pool1 = MaxPooling2D(pool_size=(2,2),name='maxpool1')(conv1) 
conv2 = Conv2D(32, (3,3), activation=act, padding='same',name='encoder2_cov')(pool1)
pool2 = MaxPooling2D(pool_size=(2,2),name='maxpool2')(conv2) 
encoded = Conv2D(64, (3,3), activation=act, padding='same',name='encoder3_cov')(pool2) 

# Decoder1
conv4 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder1_cov')(encoded)
up1 = UpSampling2D((2,2),name='up1')(conv4)
conv5 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder2_cov')(up1)
up2 = UpSampling2D((2,2),name='up2')(conv5)

# Decoder2
conv6 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder3_cov')(encoded)
up3 = UpSampling2D((2,2),name='up3')(conv6)
conv7 = Conv2D(32, (3,3), activation=act, padding='same',name='decoder4_cov')(up3)
up4 = UpSampling2D((2,2),name='up4')(conv7)
#Merge
con=Concatenate()([up2,up4])
conv8 = Conv2D(64, (3,3), activation=act, padding='same',name='decoder5_cov')(con)
decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same',name='result_cov')(conv8)

# %%
# CAEFilter Image
autoencoder_sp = Model(input_img, decoded)
autoencoder_sp.compile(loss='mean_squared_error',optimizer=optimizers.Adam())
autoencoder_sp.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  encoder1_cov (Conv2D)          (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  maxpool1 (MaxPooling2D)        (None, 64, 64, 16)   0           ['encoder1_cov[0][0]']
#
#  encoder2_cov (Conv2D)          (None, 64, 64, 32)   4640        ['maxpool1[0][0]']
#
#  maxpool2 (MaxPooling2D)        (None, 32, 32, 32)   0           ['encoder2_cov[0][0]']
#
#  encoder3_cov (Conv2D)          (None, 32, 32, 64)   18496       ['maxpool2[0][0]']
#
#  decoder1_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  decoder3_cov (Conv2D)          (None, 32, 32, 64)   36928       ['encoder3_cov[0][0]']
#
#  up1 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder1_cov[0][0]']
#
#  up3 (UpSampling2D)             (None, 64, 64, 64)   0           ['decoder3_cov[0][0]']
#
#  decoder2_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up1[0][0]']
#
#  decoder4_cov (Conv2D)          (None, 64, 64, 32)   18464       ['up3[0][0]']
#
#  up2 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder2_cov[0][0]']
#                                 )
#
#  up4 (UpSampling2D)             (None, 128, 128, 32  0           ['decoder4_cov[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 128, 128, 64  0           ['up2[0][0]',
#                                 )                                 'up4[0][0]']
#
#  decoder5_cov (Conv2D)          (None, 128, 128, 64  36928       ['concatenate[0][0]']
#                                 )
#
#  result_cov (Conv2D)            (None, 128, 128, 1)  577         ['decoder5_cov[0][0]']
#
# ==================================================================================================
# Total params: 171,585
# Trainable params: 171,585
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train_cae = x_train.reshape(5067, 128, 128, 1)
x_test_cae = x_test.reshape(1267, 128, 128,1)
x_train_cae_sp_noisy = x_train_sp_noisy.reshape(5067, 128, 128, 1)
x_test_cae_sp_noisy = x_test_sp_noisy.reshape(1267, 128, 128,1)

# %%
autoencodersp_train = autoencoder_sp.fit(x_train_cae_sp_noisy, x_train_cae, 
                                    batch_size=9, 
                                    epochs=epochs, 
                                    verbose=2,
                                    validation_data=(x_test_cae_sp_noisy, x_test_cae))
# Out:
# Epoch 1/100
# 563/563 - 7s - loss: 0.0032 - val_loss: 9.4364e-04 - 7s/epoch - 13ms/step
# Epoch 2/100
# 563/563 - 4s - loss: 8.5780e-04 - val_loss: 7.1722e-04 - 4s/epoch - 8ms/step
# Epoch 3/100
# 563/563 - 5s - loss: 7.0502e-04 - val_loss: 6.4729e-04 - 5s/epoch - 8ms/step
# Epoch 4/100
# 563/563 - 5s - loss: 6.0036e-04 - val_loss: 5.9754e-04 - 5s/epoch - 8ms/step
# Epoch 5/100
# 563/563 - 5s - loss: 5.5752e-04 - val_loss: 4.9520e-04 - 5s/epoch - 8ms/step
# Epoch 6/100
# 563/563 - 5s - loss: 5.0708e-04 - val_loss: 6.1325e-04 - 5s/epoch - 8ms/step
# Epoch 7/100
# 563/563 - 5s - loss: 4.8171e-04 - val_loss: 4.3239e-04 - 5s/epoch - 8ms/step
# Epoch 8/100
# 563/563 - 5s - loss: 4.6138e-04 - val_loss: 6.3762e-04 - 5s/epoch - 8ms/step
# Epoch 9/100
# 563/563 - 5s - loss: 4.4762e-04 - val_loss: 4.0237e-04 - 5s/epoch - 8ms/step
# Epoch 10/100
# 563/563 - 5s - loss: 4.1333e-04 - val_loss: 3.9297e-04 - 5s/epoch - 8ms/step
# Epoch 11/100
# 563/563 - 5s - loss: 4.0957e-04 - val_loss: 3.6987e-04 - 5s/epoch - 8ms/step
# Epoch 12/100
# 563/563 - 5s - loss: 3.8259e-04 - val_loss: 3.5649e-04 - 5s/epoch - 9ms/step
# Epoch 13/100
# 563/563 - 5s - loss: 3.7182e-04 - val_loss: 3.4058e-04 - 5s/epoch - 8ms/step
# Epoch 14/100
# 563/563 - 5s - loss: 3.5536e-04 - val_loss: 3.4274e-04 - 5s/epoch - 9ms/step
# Epoch 15/100
# 563/563 - 5s - loss: 3.6441e-04 - val_loss: 3.4711e-04 - 5s/epoch - 9ms/step
# Epoch 16/100
# 563/563 - 5s - loss: 3.2151e-04 - val_loss: 3.2472e-04 - 5s/epoch - 9ms/step
# Epoch 17/100
# 563/563 - 5s - loss: 3.2942e-04 - val_loss: 3.0448e-04 - 5s/epoch - 9ms/step
# Epoch 18/100
# 563/563 - 5s - loss: 3.2185e-04 - val_loss: 2.9044e-04 - 5s/epoch - 9ms/step
# Epoch 19/100
# 563/563 - 5s - loss: 3.0418e-04 - val_loss: 2.8133e-04 - 5s/epoch - 9ms/step
# Epoch 20/100
# 563/563 - 5s - loss: 2.9334e-04 - val_loss: 2.7702e-04 - 5s/epoch - 9ms/step
# Epoch 21/100
# 563/563 - 5s - loss: 2.9011e-04 - val_loss: 2.7566e-04 - 5s/epoch - 9ms/step
# Epoch 22/100
# 563/563 - 5s - loss: 2.8857e-04 - val_loss: 3.4102e-04 - 5s/epoch - 9ms/step
# Epoch 23/100
# 563/563 - 5s - loss: 2.7717e-04 - val_loss: 2.9540e-04 - 5s/epoch - 9ms/step
# Epoch 24/100
# 563/563 - 5s - loss: 2.9240e-04 - val_loss: 2.6204e-04 - 5s/epoch - 9ms/step
# Epoch 25/100
# 563/563 - 5s - loss: 2.5308e-04 - val_loss: 2.5141e-04 - 5s/epoch - 9ms/step
# Epoch 26/100
# 563/563 - 5s - loss: 2.5613e-04 - val_loss: 2.3901e-04 - 5s/epoch - 9ms/step
# Epoch 27/100
# 563/563 - 5s - loss: 2.5411e-04 - val_loss: 2.3917e-04 - 5s/epoch - 9ms/step
# Epoch 28/100
# 563/563 - 5s - loss: 2.4912e-04 - val_loss: 2.3415e-04 - 5s/epoch - 9ms/step
# Epoch 29/100
# 563/563 - 5s - loss: 2.4335e-04 - val_loss: 2.3951e-04 - 5s/epoch - 9ms/step
# Epoch 30/100
# 563/563 - 5s - loss: 2.4998e-04 - val_loss: 2.2279e-04 - 5s/epoch - 9ms/step
# Epoch 31/100
# 563/563 - 5s - loss: 2.3534e-04 - val_loss: 2.9308e-04 - 5s/epoch - 9ms/step
# Epoch 32/100
# 563/563 - 5s - loss: 2.3336e-04 - val_loss: 2.3351e-04 - 5s/epoch - 9ms/step
# Epoch 33/100
# 563/563 - 5s - loss: 2.2651e-04 - val_loss: 2.1827e-04 - 5s/epoch - 9ms/step
# Epoch 34/100
# 563/563 - 5s - loss: 2.4083e-04 - val_loss: 2.2411e-04 - 5s/epoch - 9ms/step
# Epoch 35/100
# 563/563 - 5s - loss: 2.1431e-04 - val_loss: 2.1042e-04 - 5s/epoch - 9ms/step
# Epoch 36/100
# 563/563 - 5s - loss: 2.1719e-04 - val_loss: 2.1163e-04 - 5s/epoch - 9ms/step
# Epoch 37/100
# 563/563 - 5s - loss: 2.3066e-04 - val_loss: 2.0300e-04 - 5s/epoch - 9ms/step
# Epoch 38/100
# 563/563 - 5s - loss: 2.0986e-04 - val_loss: 2.0489e-04 - 5s/epoch - 9ms/step
# Epoch 39/100
# 563/563 - 5s - loss: 2.0637e-04 - val_loss: 1.9911e-04 - 5s/epoch - 9ms/step
# Epoch 40/100
# 563/563 - 5s - loss: 2.1076e-04 - val_loss: 2.1334e-04 - 5s/epoch - 9ms/step
# Epoch 41/100
# 563/563 - 5s - loss: 1.9803e-04 - val_loss: 2.0534e-04 - 5s/epoch - 9ms/step
# Epoch 42/100
# 563/563 - 5s - loss: 2.4591e-04 - val_loss: 1.9600e-04 - 5s/epoch - 9ms/step
# Epoch 43/100
# 563/563 - 5s - loss: 1.9402e-04 - val_loss: 2.0162e-04 - 5s/epoch - 9ms/step
# Epoch 44/100
# 563/563 - 5s - loss: 1.9702e-04 - val_loss: 1.9618e-04 - 5s/epoch - 9ms/step
# Epoch 45/100
# 563/563 - 5s - loss: 2.1810e-04 - val_loss: 2.8087e-04 - 5s/epoch - 9ms/step
# Epoch 46/100
# 563/563 - 5s - loss: 1.9152e-04 - val_loss: 1.8322e-04 - 5s/epoch - 9ms/step
# Epoch 47/100
# 563/563 - 5s - loss: 1.9008e-04 - val_loss: 1.8740e-04 - 5s/epoch - 9ms/step
# Epoch 48/100
# 563/563 - 5s - loss: 1.8895e-04 - val_loss: 1.8322e-04 - 5s/epoch - 9ms/step
# Epoch 49/100
# 563/563 - 5s - loss: 1.8873e-04 - val_loss: 1.8467e-04 - 5s/epoch - 9ms/step
# Epoch 50/100
# 563/563 - 5s - loss: 1.8243e-04 - val_loss: 1.7823e-04 - 5s/epoch - 9ms/step
# Epoch 51/100
# 563/563 - 5s - loss: 1.9046e-04 - val_loss: 2.0297e-04 - 5s/epoch - 9ms/step
# Epoch 52/100
# 563/563 - 5s - loss: 1.8090e-04 - val_loss: 1.7318e-04 - 5s/epoch - 9ms/step
# Epoch 53/100
# 563/563 - 5s - loss: 1.8416e-04 - val_loss: 1.7157e-04 - 5s/epoch - 9ms/step
# Epoch 54/100
# 563/563 - 5s - loss: 1.7823e-04 - val_loss: 1.7437e-04 - 5s/epoch - 9ms/step
# Epoch 55/100
# 563/563 - 5s - loss: 1.8214e-04 - val_loss: 1.7146e-04 - 5s/epoch - 9ms/step
# Epoch 56/100
# 563/563 - 5s - loss: 1.7999e-04 - val_loss: 1.6804e-04 - 5s/epoch - 9ms/step
# Epoch 57/100
# 563/563 - 5s - loss: 1.7390e-04 - val_loss: 1.6662e-04 - 5s/epoch - 9ms/step
# Epoch 58/100
# 563/563 - 5s - loss: 1.7959e-04 - val_loss: 1.6578e-04 - 5s/epoch - 9ms/step
# Epoch 59/100
# 563/563 - 5s - loss: 1.7106e-04 - val_loss: 2.1660e-04 - 5s/epoch - 9ms/step
# Epoch 60/100
# 563/563 - 5s - loss: 1.7179e-04 - val_loss: 1.6320e-04 - 5s/epoch - 9ms/step
# Epoch 61/100
# 563/563 - 5s - loss: 1.6607e-04 - val_loss: 1.6522e-04 - 5s/epoch - 9ms/step
# Epoch 62/100
# 563/563 - 5s - loss: 1.7325e-04 - val_loss: 1.6855e-04 - 5s/epoch - 9ms/step
# Epoch 63/100
# 563/563 - 5s - loss: 1.6557e-04 - val_loss: 1.5996e-04 - 5s/epoch - 9ms/step
# Epoch 64/100
# 563/563 - 5s - loss: 1.6628e-04 - val_loss: 2.0194e-04 - 5s/epoch - 9ms/step
# Epoch 65/100
# 563/563 - 5s - loss: 1.6865e-04 - val_loss: 1.6596e-04 - 5s/epoch - 9ms/step
# Epoch 66/100
# 563/563 - 5s - loss: 1.7222e-04 - val_loss: 1.6555e-04 - 5s/epoch - 9ms/step
# Epoch 67/100
# 563/563 - 5s - loss: 1.5899e-04 - val_loss: 2.1337e-04 - 5s/epoch - 9ms/step
# Epoch 68/100
# 563/563 - 5s - loss: 1.6103e-04 - val_loss: 1.6194e-04 - 5s/epoch - 9ms/step
# Epoch 69/100
# 563/563 - 5s - loss: 1.6109e-04 - val_loss: 1.5869e-04 - 5s/epoch - 9ms/step
# Epoch 70/100
# 563/563 - 5s - loss: 1.5983e-04 - val_loss: 1.5358e-04 - 5s/epoch - 9ms/step
# Epoch 71/100
# 563/563 - 5s - loss: 1.5649e-04 - val_loss: 1.5689e-04 - 5s/epoch - 9ms/step
# Epoch 72/100
# 563/563 - 5s - loss: 1.9968e-04 - val_loss: 1.5607e-04 - 5s/epoch - 9ms/step
# Epoch 73/100
# 563/563 - 5s - loss: 1.5343e-04 - val_loss: 1.5221e-04 - 5s/epoch - 9ms/step
# Epoch 74/100
# 563/563 - 5s - loss: 1.5774e-04 - val_loss: 1.5183e-04 - 5s/epoch - 9ms/step
# Epoch 75/100
# 563/563 - 5s - loss: 1.5629e-04 - val_loss: 1.5547e-04 - 5s/epoch - 9ms/step
# Epoch 76/100
# 563/563 - 5s - loss: 1.5627e-04 - val_loss: 1.4757e-04 - 5s/epoch - 9ms/step
# Epoch 77/100
# 563/563 - 5s - loss: 1.5668e-04 - val_loss: 1.4966e-04 - 5s/epoch - 9ms/step
# Epoch 78/100
# 563/563 - 5s - loss: 1.5825e-04 - val_loss: 1.4837e-04 - 5s/epoch - 9ms/step
# Epoch 79/100
# 563/563 - 5s - loss: 1.5735e-04 - val_loss: 1.4739e-04 - 5s/epoch - 9ms/step
# Epoch 80/100
# 563/563 - 5s - loss: 1.5031e-04 - val_loss: 1.6296e-04 - 5s/epoch - 9ms/step
# Epoch 81/100
# 563/563 - 5s - loss: 1.5963e-04 - val_loss: 1.6403e-04 - 5s/epoch - 9ms/step
# Epoch 82/100
# 563/563 - 5s - loss: 1.4704e-04 - val_loss: 1.5463e-04 - 5s/epoch - 9ms/step
# Epoch 83/100
# 563/563 - 5s - loss: 1.5184e-04 - val_loss: 1.5335e-04 - 5s/epoch - 9ms/step
# Epoch 84/100
# 563/563 - 5s - loss: 1.4946e-04 - val_loss: 1.4476e-04 - 5s/epoch - 9ms/step
# Epoch 85/100
# 563/563 - 5s - loss: 1.4861e-04 - val_loss: 1.4379e-04 - 5s/epoch - 9ms/step
# Epoch 86/100
# 563/563 - 5s - loss: 1.5199e-04 - val_loss: 1.4287e-04 - 5s/epoch - 9ms/step
# Epoch 87/100
# 563/563 - 5s - loss: 1.4969e-04 - val_loss: 1.5406e-04 - 5s/epoch - 9ms/step
# Epoch 88/100
# 563/563 - 5s - loss: 1.4667e-04 - val_loss: 1.4456e-04 - 5s/epoch - 9ms/step
# Epoch 89/100
# 563/563 - 5s - loss: 1.4562e-04 - val_loss: 1.4223e-04 - 5s/epoch - 9ms/step
# Epoch 90/100
# 563/563 - 5s - loss: 1.4729e-04 - val_loss: 1.4231e-04 - 5s/epoch - 9ms/step
# Epoch 91/100
# 563/563 - 5s - loss: 1.4369e-04 - val_loss: 1.4661e-04 - 5s/epoch - 9ms/step
# Epoch 92/100
# 563/563 - 5s - loss: 1.5024e-04 - val_loss: 1.4526e-04 - 5s/epoch - 9ms/step
# Epoch 93/100
# 563/563 - 5s - loss: 1.4396e-04 - val_loss: 1.5183e-04 - 5s/epoch - 9ms/step
# Epoch 94/100
# 563/563 - 5s - loss: 1.4471e-04 - val_loss: 1.4067e-04 - 5s/epoch - 9ms/step
# Epoch 95/100
# 563/563 - 5s - loss: 1.4444e-04 - val_loss: 1.4749e-04 - 5s/epoch - 9ms/step
# Epoch 96/100
# 563/563 - 5s - loss: 1.4482e-04 - val_loss: 1.3861e-04 - 5s/epoch - 9ms/step
# Epoch 97/100
# 563/563 - 5s - loss: 1.4164e-04 - val_loss: 1.3935e-04 - 5s/epoch - 9ms/step
# Epoch 98/100
# 563/563 - 5s - loss: 1.4291e-04 - val_loss: 1.4562e-04 - 5s/epoch - 9ms/step
# Epoch 99/100
# 563/563 - 5s - loss: 1.4260e-04 - val_loss: 1.4668e-04 - 5s/epoch - 9ms/step
# Epoch 100/100
# 563/563 - 5s - loss: 1.3914e-04 - val_loss: 1.4315e-04 - 5s/epoch - 9ms/step

# %%
start = time.time()
cae_x_test_sp_noisy = autoencoder_sp.predict(x_test_cae_sp_noisy)
print(cae_x_test_sp_noisy.shape)
end = time.time()
Caetime= end - start
print("CPU 시간 : "+str(Caetime))
cae_x_test_sp_noisy = cae_x_test_sp_noisy.reshape(1267, 128, 128)
# Out:
# 40/40 [==============================] - 1s 12ms/step
# (1267, 128, 128, 1)
# CPU 시간 : 0.8418292999267578

# %%
ax = plt.subplot()
plt.imshow(cae_x_test_sp_noisy[1200], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Improved CAEfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
cae_loss = autoencodersp_train.history['loss']
cae_val_loss = autoencodersp_train.history['val_loss']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")
plt.plot(epochs, cae_val_loss, 'g', label="test")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
from skimage.metrics import structural_similarity as ssim

# %%
psnr_mean = []
mae_mean = []
psnr_median = []
mae_median = []
mae_lee = []
psnr_lee = []
psnr_cae = []
mae_cae = []

ssim_mean=[]
ssim_median=[]
ssim_lee=[]
ssim_cae=[]

for i in range(len(x_test_sp_noisy)):
    mae_mean.append(MAE(mean_x_test_sp_noisy[i],x_test[i]))
    mae_median.append(MAE(median_x_test_sp_noisy[i],x_test[i]))
    mae_lee.append(MAE(lee_x_test_sp_noisy[i],x_test[i]))
    mae_cae.append(MAE(cae_x_test_sp_noisy[i],x_test[i]))
    #print(cae_x_test_sp_noisy[i].shape)
    #print(x_test[i].shape)
    psnr_mean.append(PSNR(mean_x_test_sp_noisy[i],x_test[i]))
    psnr_median.append(PSNR(median_x_test_sp_noisy[i],x_test[i]))
    psnr_lee.append(PSNR(lee_x_test_sp_noisy[i],x_test[i]))
    psnr_cae.append(PSNR(cae_x_test_sp_noisy[i],x_test[i]))
    ssim_mean.append(ssim(x_test[i], mean_x_test_sp_noisy[i]))#,data_range=mean_x_test_sp_noisy[i].max() - mean_x_test_sp_noisy[i].min()))
    ssim_median.append(ssim(x_test[i], median_x_test_sp_noisy[i]))#,data_range=median_x_test_sp_noisy[i].max() - median_x_test_sp_noisy[i].min()))
    ssim_lee.append(ssim(x_test[i], lee_x_test_sp_noisy[i]))#,data_range=lee_x_test_sp_noisy[i].max() - lee_x_test_sp_noisy[i].min()))
    
    
    ssim_cae.append(ssim(x_test[i], cae_x_test_sp_noisy[i]))#,data_range=cae_x_test_sp_noisy[i].max() - cae_x_test_sp_noisy[i].min()))

# %%
print("About Gauss Noisy")
print("Mean Filter : MAE = " +  str(np.mean(mae_mean)) + " & PSNR = " + str(np.mean(psnr_mean))+" & SSIM = "+str(np.mean(ssim_mean)))
print("Median Filter : MAE = " +  str(np.mean(mae_median)) + " & PSNR = " + str(np.mean(psnr_median))+" & SSIM = "+str(np.mean(ssim_median)))
print("LEE Filter : MAE = " +  str(np.mean(mae_lee)) + " & PSNR = " + str(np.mean(psnr_lee))+" & SSIM = "+str(np.mean(ssim_lee)))
print("CAE Filter : MAE = " +  str(np.mean(mae_cae)) + " & PSNR = " + str(np.mean(psnr_cae))+" & SSIM = "+str(np.mean(ssim_cae)))
# Out:
# About Gauss Noisy
# Mean Filter : MAE = 0.028688308728841313 & PSNR = 26.508376827485996 & SSIM = 0.7966570155361866
# Median Filter : MAE = 0.006511915234732444 & PSNR = 35.57966689506303 & SSIM = 0.9838886780426864
# LEE Filter : MAE = 0.029153911787926968 & PSNR = 22.228361781319897 & SSIM = 0.6469154547297533
# CAE Filter : MAE = 0.007585728227455497 & PSNR = 39.02586402644834 & SSIM = 0.9871476093545427
